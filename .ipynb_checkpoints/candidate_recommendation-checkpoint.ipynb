# %% [markdown]
# # Candidate Recommendation System
# ****

# %% [markdown]
# # Importing the Libraries
# ****

# %%
from datetime import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller, acf, pacf,arma_order_select_ic
from pmdarima.arima import auto_arima
import xgboost as xgb
from tensorflow import keras
import lightgbm as lgb
import itertools 
import calendar

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Get the data
# ****

# %% [markdown]
# ## Importing The Data
# ****

# %% [markdown]
# Connecting to the API as the data source.

# %%
X_train = pd.read_csv('sample_datasheet.csv')

# %% [markdown]
# ## Data Format Converting
# ****
#
# Changing the file type if needed

# %%
#X_train = pd.read_csv('X_train.tsv', delimiter='\t', decimal=",")
#X_train.to_csv("X_train_csv.csv", sep=',', encoding='utf-8', quotechar='"', decimal='.')

# %% [markdown]
# # Looking Into The Data
# ****

# %%
X_train.head()
# Out:
#                             id          full_name first_name middle_initial  \
# 0  iQI5CVMbb6pbBtfxN5Boaw_0000      inguna sotelo     inguna            NaN
# 1  8waE0H55HkL60xQcjtVe7A_0000           jon katz        jon            NaN
# 2  RcwvSHEBVA1-BVD4uQH3Bg_0000       paul zagaris       paul            NaN
# 3  9k7BrMwL84x4Gcs9MmUQHQ_0000     brandon gramse    brandon            NaN
# 4  jtBLj1MfEyWbsKRDmGmftg_0000  ryshelle mccadney   ryshelle            NaN
#
#    middle_name last_name  gender  birth_year  birth_date  \
# 0          NaN    sotelo  female      1963.0     1963-03
# 1          NaN      katz    male         NaN         NaN
# 2          NaN   zagaris    male      1981.0  17/05/1981
# 3          NaN    gramse    male      1994.0         NaN
# 4          NaN  mccadney  female         NaN         NaN
#
#                               linkedin_url  ... phone_numbers/7  \
# 0   linkedin.com/in/inguna-sotelo-9b000213  ...             NaN
# 1                  linkedin.com/in/jonkatz  ...             NaN
# 2              linkedin.com/in/cinematicac  ...             NaN
# 3  linkedin.com/in/brandon-gramse-83675b18  ...             NaN
# 4         linkedin.com/in/ryshellemccadney  ...             NaN
#
#    phone_numbers/8 phone_numbers/9 phone_numbers/10  education/0/majors/1  \
# 0              NaN             NaN              NaN                   NaN
# 1              NaN             NaN              NaN                   NaN
# 2              NaN             NaN              NaN                   NaN
# 3              NaN             NaN              NaN                   NaN
# 4              NaN             NaN              NaN                   NaN
#
#   education/1/majors/1 education/1/majors/2  version_status/contains/0  \
# 0                  NaN                  NaN                        NaN
# 1                  NaN                  NaN                        NaN
# 2                  NaN                  NaN                        NaN
# 3                  NaN                  NaN                        NaN
# 4                  NaN                  NaN                        NaN
#
#    version_status/contains/1 education/4/majors/2
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
#
# [5 rows x 1168 columns]

# %%
X_train.describe()
# Out:
#        middle_name   birth_year   linkedin_id   facebook_id  github_url  \
# count          0.0     7.000000  1.000000e+01  9.000000e+00         0.0
# mean           NaN  1975.714286  6.647377e+07  3.333405e+13         NaN
# std            NaN    18.391251  1.072827e+08  5.000046e+13         NaN
# min            NaN  1940.000000  7.576737e+06  1.404029e+06         NaN
# 25%            NaN  1971.500000  2.007478e+07  1.420133e+07         NaN
# 50%            NaN  1981.000000  3.880211e+07  5.751614e+08         NaN
# 75%            NaN  1986.000000  4.642971e+07  1.000000e+14         NaN
# max            NaN  1994.000000  3.681012e+08  1.000030e+14         NaN
#
#        github_username  mobile_phone  job_title_role  job_title_sub_role  \
# count              0.0  1.000000e+01             0.0                 0.0
# mean               NaN  1.679923e+10             NaN                 NaN
# std                NaN  2.196591e+09             NaN                 NaN
# min                NaN  1.209614e+10             NaN                 NaN
# 25%                NaN  1.591126e+10             NaN                 NaN
# 50%                NaN  1.669929e+10             NaN                 NaN
# 75%                NaN  1.861684e+10             NaN                 NaN
# max                NaN  1.949437e+10             NaN                 NaN
#
#        job_company_founded  ...  experience/10/company/twitter_url  \
# count            10.000000  ...                                0.0
# mean           1957.700000  ...                                NaN
# std              72.200416  ...                                NaN
# min            1812.000000  ...                                NaN
# 25%            1942.750000  ...                                NaN
# 50%            1991.000000  ...                                NaN
# 75%            2007.750000  ...                                NaN
# max            2016.000000  ...                                NaN
#
#        experience/10/end_date  experience/10/title/role  \
# count                     0.0                       0.0
# mean                      NaN                       NaN
# std                       NaN                       NaN
# min                       NaN                       NaN
# 25%                       NaN                       NaN
# 50%                       NaN                       NaN
# 75%                       NaN                       NaN
# max                       NaN                       NaN
#
#        experience/10/title/sub_role  phone_numbers/5  phone_numbers/6  \
# count                           0.0     1.000000e+00     1.000000e+00
# mean                            NaN     1.703404e+10     1.703754e+10
# std                             NaN              NaN              NaN
# min                             NaN     1.703404e+10     1.703754e+10
# 25%                             NaN     1.703404e+10     1.703754e+10
# 50%                             NaN     1.703404e+10     1.703754e+10
# 75%                             NaN     1.703404e+10     1.703754e+10
# max                             NaN     1.703404e+10     1.703754e+10
#
#        phone_numbers/7  phone_numbers/8  phone_numbers/9  phone_numbers/10
# count     1.000000e+00     1.000000e+00     1.000000e+00      1.000000e+00
# mean      1.703754e+10     1.703859e+10     1.301802e+10      1.937649e+10
# std                NaN              NaN              NaN               NaN
# min       1.703754e+10     1.703859e+10     1.301802e+10      1.937649e+10
# 25%       1.703754e+10     1.703859e+10     1.301802e+10      1.937649e+10
# 50%       1.703754e+10     1.703859e+10     1.301802e+10      1.937649e+10
# 75%       1.703754e+10     1.703859e+10     1.301802e+10      1.937649e+10
# max       1.703754e+10     1.703859e+10     1.301802e+10      1.937649e+10
#
# [8 rows x 181 columns]

# %%
X_train.dtypes
# Out:
# id                            object
# full_name                     object
# first_name                    object
# middle_initial                object
# middle_name                  float64
#                               ...
# education/1/majors/1          object
# education/1/majors/2          object
# version_status/contains/0     object
# version_status/contains/1     object
# education/4/majors/2          object
# Length: 1168, dtype: object

# %% [markdown]
# Distinct categorical variable values:

# %%
#X_train["key"].value_counts()

# %% [markdown]
# Another way to get distinct values but easier to see all the values:

# %%
#np.unique(X_train["key"])

# %% [markdown]
# # Dealing with Missing Values
# ****

# %%
def missing_data_percentage(column):
    percentage = (X_train[column].isna().sum()/len(X_train[column])) * 100
    print('{} column - missing data percentage: {:.2f} %' .format(column, percentage))
    return float(percentage)

# %% [markdown]
# The columns with more than 50% of missing values will be removed from the dataset:

# %%
for column in X_train.columns:
    percentage = missing_data_percentage(column)
    if percentage > 50:
        X_train = X_train.drop(column, axis = 1)
# Out:
# id column - missing data percentage: 0.00 %
# middle_initial column - missing data percentage: 80.00 %
# middle_name column - missing data percentage: 100.00 %
# birth_year column - missing data percentage: 30.00 %
# github_username column - missing data percentage: 100.00 %
# industry column - missing data percentage: 0.00 %
# job_title column - missing data percentage: 0.00 %
# job_title_role column - missing data percentage: 100.00 %
# job_title_sub_role column - missing data percentage: 100.00 %
# job_title_levels/0 column - missing data percentage: 0.00 %
# job_company_id column - missing data percentage: 0.00 %
# job_company_name column - missing data percentage: 0.00 %
# job_company_size column - missing data percentage: 0.00 %
# job_company_industry column - missing data percentage: 0.00 %
# job_company_location_name column - missing data percentage: 0.00 %
# job_company_location_locality column - missing data percentage: 0.00 %
# job_company_location_region column - missing data percentage: 0.00 %
# job_company_location_address_line_2 column - missing data percentage: 80.00 %
# job_company_location_country column - missing data percentage: 0.00 %
# location_name column - missing data percentage: 0.00 %
# location_locality column - missing data percentage: 0.00 %
# location_region column - missing data percentage: 0.00 %
# location_country column - missing data percentage: 0.00 %
# location_address_line_2 column - missing data percentage: 100.00 %
# location_geo column - missing data percentage: 0.00 %
# location_last_updated column - missing data percentage: 0.00 %
# skills/0 column - missing data percentage: 0.00 %
# skills/1 column - missing data percentage: 0.00 %
# skills/2 column - missing data percentage: 0.00 %
# skills/3 column - missing data percentage: 0.00 %
# skills/4 column - missing data percentage: 0.00 %
# skills/5 column - missing data percentage: 0.00 %
# skills/6 column - missing data percentage: 0.00 %
# skills/7 column - missing data percentage: 0.00 %
# skills/8 column - missing data percentage: 0.00 %
# skills/9 column - missing data percentage: 0.00 %
# skills/10 column - missing data percentage: 0.00 %
# skills/11 column - missing data percentage: 20.00 %
# skills/12 column - missing data percentage: 20.00 %
# skills/13 column - missing data percentage: 20.00 %
# skills/14 column - missing data percentage: 20.00 %
# skills/15 column - missing data percentage: 30.00 %
# skills/16 column - missing data percentage: 30.00 %
# skills/17 column - missing data percentage: 30.00 %
# skills/18 column - missing data percentage: 40.00 %
# skills/19 column - missing data percentage: 50.00 %
# skills/20 column - missing data percentage: 50.00 %
# skills/21 column - missing data percentage: 50.00 %
# skills/22 column - missing data percentage: 50.00 %
# skills/23 column - missing data percentage: 50.00 %
# skills/24 column - missing data percentage: 50.00 %
# skills/25 column - missing data percentage: 60.00 %
# skills/26 column - missing data percentage: 60.00 %
# skills/27 column - missing data percentage: 60.00 %
# skills/28 column - missing data percentage: 60.00 %
# skills/29 column - missing data percentage: 60.00 %
# skills/30 column - missing data percentage: 60.00 %
# skills/31 column - missing data percentage: 60.00 %
# skills/32 column - missing data percentage: 60.00 %
# location_names/0 column - missing data percentage: 0.00 %
# location_names/1 column - missing data percentage: 0.00 %
# location_names/2 column - missing data percentage: 10.00 %
# location_names/3 column - missing data percentage: 10.00 %
# regions/0 column - missing data percentage: 0.00 %
# countries/0 column - missing data percentage: 0.00 %
# experience/0/company/size column - missing data percentage: 40.00 %
# experience/0/company/industry column - missing data percentage: 40.00 %
# experience/0/company/location/name column - missing data percentage: 40.00 %
# experience/0/company/location/locality column - missing data percentage: 50.00 %
# experience/0/company/location/region column - missing data percentage: 50.00 %
# experience/0/company/location/country column - missing data percentage: 40.00 %
# experience/0/company/location/address_line_2 column - missing data percentage: 80.00 %
# experience/0/location_names/0 column - missing data percentage: 90.00 %
# experience/0/title/name column - missing data percentage: 0.00 %
# experience/0/title/role column - missing data percentage: 50.00 %
# experience/0/title/sub_role column - missing data percentage: 70.00 %
# experience/0/title/levels/0 column - missing data percentage: 40.00 %
# experience/1/company/size column - missing data percentage: 30.00 %
# experience/1/company/industry column - missing data percentage: 30.00 %
# experience/1/company/location/name column - missing data percentage: 30.00 %
# experience/1/company/location/locality column - missing data percentage: 30.00 %
# experience/1/company/location/region column - missing data percentage: 30.00 %
# experience/1/company/location/country column - missing data percentage: 30.00 %
# experience/1/company/location/address_line_2 column - missing data percentage: 90.00 %
# experience/1/location_names/0 column - missing data percentage: 60.00 %
# experience/1/title/name column - missing data percentage: 0.00 %
# experience/1/title/role column - missing data percentage: 40.00 %
# experience/1/title/sub_role column - missing data percentage: 70.00 %
# education/0/school/type column - missing data percentage: 10.00 %
# education/0/school/location/name column - missing data percentage: 30.00 %
# education/0/school/location/locality column - missing data percentage: 30.00 %
# education/0/school/location/region column - missing data percentage: 30.00 %
# education/0/school/location/country column - missing data percentage: 30.00 %
# education/0/gpa column - missing data percentage: 100.00 %
# education/1/school/type column - missing data percentage: 10.00 %
# education/1/school/location/name column - missing data percentage: 30.00 %
# education/1/school/location/locality column - missing data percentage: 30.00 %
# education/1/school/location/region column - missing data percentage: 40.00 %
# education/1/school/location/country column - missing data percentage: 30.00 %
# education/1/gpa column - missing data percentage: 90.00 %
# skills/33 column - missing data percentage: 70.00 %
# skills/34 column - missing data percentage: 70.00 %
# skills/35 column - missing data percentage: 70.00 %
# skills/36 column - missing data percentage: 70.00 %
# skills/37 column - missing data percentage: 70.00 %
# skills/38 column - missing data percentage: 70.00 %
# skills/39 column - missing data percentage: 70.00 %
# skills/40 column - missing data percentage: 70.00 %
# skills/41 column - missing data percentage: 70.00 %
# skills/42 column - missing data percentage: 70.00 %
# skills/43 column - missing data percentage: 70.00 %
# skills/44 column - missing data percentage: 70.00 %
# skills/45 column - missing data percentage: 70.00 %
# skills/46 column - missing data percentage: 70.00 %
# skills/47 column - missing data percentage: 70.00 %
# skills/48 column - missing data percentage: 70.00 %
# skills/49 column - missing data percentage: 70.00 %
# location_names/4 column - missing data percentage: 30.00 %
# location_names/5 column - missing data percentage: 40.00 %
# location_names/6 column - missing data percentage: 40.00 %
# location_names/7 column - missing data percentage: 40.00 %
# location_names/8 column - missing data percentage: 50.00 %
# location_names/9 column - missing data percentage: 60.00 %
# location_names/10 column - missing data percentage: 60.00 %
# location_names/11 column - missing data percentage: 80.00 %
# location_names/12 column - missing data percentage: 80.00 %
# location_names/13 column - missing data percentage: 80.00 %
# location_names/14 column - missing data percentage: 80.00 %
# location_names/15 column - missing data percentage: 80.00 %
# regions/1 column - missing data percentage: 20.00 %
# regions/2 column - missing data percentage: 40.00 %
# regions/3 column - missing data percentage: 40.00 %
# regions/4 column - missing data percentage: 60.00 %
# regions/5 column - missing data percentage: 60.00 %
# regions/6 column - missing data percentage: 70.00 %
# regions/7 column - missing data percentage: 70.00 %
# experience/0/company/location column - missing data percentage: 100.00 %
# experience/0/title/levels/1 column - missing data percentage: 90.00 %
# experience/1/title/levels/0 column - missing data percentage: 20.00 %
# experience/2/company/size column - missing data percentage: 20.00 %
# experience/2/company/industry column - missing data percentage: 20.00 %
# experience/2/company/location/name column - missing data percentage: 20.00 %
# experience/2/company/location/locality column - missing data percentage: 30.00 %
# experience/2/company/location/region column - missing data percentage: 30.00 %
# experience/2/company/location/country column - missing data percentage: 20.00 %
# experience/2/company/location/address_line_2 column - missing data percentage: 90.00 %
# experience/2/location_names/0 column - missing data percentage: 50.00 %
# experience/2/title/name column - missing data percentage: 10.00 %
# experience/2/title/role column - missing data percentage: 50.00 %
# experience/2/title/sub_role column - missing data percentage: 70.00 %
# experience/2/title/levels/0 column - missing data percentage: 40.00 %
# experience/3/company/size column - missing data percentage: 20.00 %
# experience/3/company/industry column - missing data percentage: 20.00 %
# experience/3/company/location/name column - missing data percentage: 20.00 %
# experience/3/company/location/locality column - missing data percentage: 20.00 %
# experience/3/company/location/region column - missing data percentage: 20.00 %
# experience/3/company/location/country column - missing data percentage: 20.00 %
# experience/3/company/location/address_line_2 column - missing data percentage: 70.00 %
# experience/3/location_names/0 column - missing data percentage: 30.00 %
# experience/3/title/name column - missing data percentage: 20.00 %
# experience/3/title/role column - missing data percentage: 90.00 %
# experience/3/title/sub_role column - missing data percentage: 100.00 %
# experience/3/title/levels/0 column - missing data percentage: 60.00 %
# experience/4/company/size column - missing data percentage: 50.00 %
# experience/4/company/industry column - missing data percentage: 50.00 %
# experience/4/company/location/name column - missing data percentage: 50.00 %
# experience/4/company/location/locality column - missing data percentage: 60.00 %
# experience/4/company/location/region column - missing data percentage: 60.00 %
# experience/4/company/location/country column - missing data percentage: 50.00 %
# experience/4/company/location/address_line_2 column - missing data percentage: 90.00 %
# experience/4/location_names/0 column - missing data percentage: 50.00 %
# experience/4/title/name column - missing data percentage: 30.00 %
# experience/4/title/role column - missing data percentage: 50.00 %
# experience/4/title/sub_role column - missing data percentage: 80.00 %
# experience/4/title/levels/0 column - missing data percentage: 70.00 %
# experience/5/company/size column - missing data percentage: 30.00 %
# experience/5/company/industry column - missing data percentage: 30.00 %
# experience/5/company/location/name column - missing data percentage: 30.00 %
# experience/5/company/location/locality column - missing data percentage: 40.00 %
# experience/5/company/location/region column - missing data percentage: 30.00 %
# experience/5/company/location/country column - missing data percentage: 30.00 %
# experience/5/company/location/address_line_2 column - missing data percentage: 100.00 %
# experience/5/location_names/0 column - missing data percentage: 40.00 %
# experience/5/title/name column - missing data percentage: 30.00 %
# experience/5/title/role column - missing data percentage: 60.00 %
# experience/5/title/sub_role column - missing data percentage: 100.00 %
# experience/5/title/levels/0 column - missing data percentage: 60.00 %
# experience/5/title/levels/1 column - missing data percentage: 90.00 %
# experience/6/company/size column - missing data percentage: 30.00 %
# experience/6/company/industry column - missing data percentage: 30.00 %
# experience/6/company/location/name column - missing data percentage: 30.00 %
# experience/6/company/location/locality column - missing data percentage: 30.00 %
# experience/6/company/location/region column - missing data percentage: 30.00 %
# experience/6/company/location/country column - missing data percentage: 30.00 %
# experience/6/company/location/address_line_2 column - missing data percentage: 100.00 %
# experience/6/title/name column - missing data percentage: 30.00 %
# experience/6/title/role column - missing data percentage: 80.00 %
# experience/6/title/sub_role column - missing data percentage: 100.00 %
# experience/6/title/levels/0 column - missing data percentage: 70.00 %
# experience/7/company/size column - missing data percentage: 60.00 %
# experience/7/company/industry column - missing data percentage: 60.00 %
# experience/7/company/location/name column - missing data percentage: 60.00 %
# experience/7/company/location/locality column - missing data percentage: 60.00 %
# experience/7/company/location/region column - missing data percentage: 60.00 %
# experience/7/company/location/country column - missing data percentage: 60.00 %
# experience/7/company/location/address_line_2 column - missing data percentage: 90.00 %
# experience/7/location_names/0 column - missing data percentage: 60.00 %
# experience/7/title/name column - missing data percentage: 60.00 %
# experience/7/title/role column - missing data percentage: 80.00 %
# experience/7/title/sub_role column - missing data percentage: 90.00 %
# experience/7/title/levels/0 column - missing data percentage: 60.00 %
# experience/8/company/size column - missing data percentage: 80.00 %
# experience/8/company/industry column - missing data percentage: 80.00 %
# experience/8/company/location/name column - missing data percentage: 80.00 %
# experience/8/company/location/locality column - missing data percentage: 80.00 %
# experience/8/company/location/region column - missing data percentage: 80.00 %
# experience/8/company/location/country column - missing data percentage: 80.00 %
# experience/8/company/location/address_line_2 column - missing data percentage: 100.00 %
# experience/8/location_names/0 column - missing data percentage: 80.00 %
# experience/8/title/name column - missing data percentage: 80.00 %
# experience/8/title/role column - missing data percentage: 100.00 %
# experience/8/title/sub_role column - missing data percentage: 100.00 %
# experience/8/title/levels/0 column - missing data percentage: 80.00 %
# experience/9/company/size column - missing data percentage: 80.00 %
# experience/9/company/industry column - missing data percentage: 80.00 %
# experience/9/company/location/name column - missing data percentage: 80.00 %
# experience/9/company/location/locality column - missing data percentage: 80.00 %
# experience/9/company/location/region column - missing data percentage: 80.00 %
# experience/9/company/location/country column - missing data percentage: 80.00 %
# experience/9/company/location/address_line_2 column - missing data percentage: 100.00 %
# experience/9/location_names/0 column - missing data percentage: 80.00 %
# experience/9/title/name column - missing data percentage: 80.00 %
# experience/9/title/role column - missing data percentage: 90.00 %
# experience/9/title/sub_role column - missing data percentage: 90.00 %
# experience/9/title/levels/0 column - missing data percentage: 80.00 %
# education/0/degrees/0 column - missing data percentage: 40.00 %
# education/0/degrees/1 column - missing data percentage: 40.00 %
# education/1/majors/0 column - missing data percentage: 60.00 %
# education/2/school/type column - missing data percentage: 30.00 %
# education/2/school/location/name column - missing data percentage: 50.00 %
# education/2/school/location/locality column - missing data percentage: 60.00 %
# education/2/school/location/region column - missing data percentage: 60.00 %
# education/2/school/location/country column - missing data percentage: 50.00 %
# education/2/gpa column - missing data percentage: 90.00 %
# education/2/degrees/0 column - missing data percentage: 50.00 %
# education/2/degrees/1 column - missing data percentage: 60.00 %
# education/3/school/type column - missing data percentage: 20.00 %
# education/3/school/location/name column - missing data percentage: 20.00 %
# education/3/school/location/locality column - missing data percentage: 20.00 %
# education/3/school/location/region column - missing data percentage: 20.00 %
# education/3/school/location/country column - missing data percentage: 20.00 %
# education/3/gpa column - missing data percentage: 90.00 %
# education/3/degrees/0 column - missing data percentage: 30.00 %
# education/3/degrees/1 column - missing data percentage: 30.00 %
# education/3/degrees/2 column - missing data percentage: 90.00 %
# education/4/school/type column - missing data percentage: 30.00 %
# education/4/school/location/name column - missing data percentage: 30.00 %
# education/4/school/location/locality column - missing data percentage: 30.00 %
# education/4/school/location/region column - missing data percentage: 30.00 %
# education/4/school/location/country column - missing data percentage: 30.00 %
# education/4/gpa column - missing data percentage: 90.00 %
# education/4/degrees/0 column - missing data percentage: 40.00 %
# education/4/degrees/1 column - missing data percentage: 40.00 %
# education/4/majors/0 column - missing data percentage: 50.00 %
# education/5/school/type column - missing data percentage: 70.00 %
# education/5/school/location/name column - missing data percentage: 70.00 %
# education/5/school/location/locality column - missing data percentage: 70.00 %
# education/5/school/location/region column - missing data percentage: 70.00 %
# education/5/school/location/country column - missing data percentage: 70.00 %
# education/5/gpa column - missing data percentage: 100.00 %
# education/5/degrees/0 column - missing data percentage: 70.00 %
# education/5/degrees/1 column - missing data percentage: 70.00 %
# education/6/school/type column - missing data percentage: 80.00 %
# education/6/school/location/name column - missing data percentage: 80.00 %
# education/6/school/location/locality column - missing data percentage: 80.00 %
# education/6/school/location/region column - missing data percentage: 80.00 %
# education/6/school/location/country column - missing data percentage: 80.00 %
# education/6/gpa column - missing data percentage: 100.00 %
# education/6/degrees/0 column - missing data percentage: 80.00 %
# education/6/degrees/1 column - missing data percentage: 80.00 %
# experience/1/company/location column - missing data percentage: 100.00 %
# experience/2/location_names/1 column - missing data percentage: 90.00 %
# education/1/degrees/0 column - missing data percentage: 80.00 %
# education/1/degrees/1 column - missing data percentage: 80.00 %
# education/2/school/location column - missing data percentage: 100.00 %
# education/2/majors/0 column - missing data percentage: 70.00 %
# education/3/majors/0 column - missing data percentage: 40.00 %
# education/3/majors/1 column - missing data percentage: 80.00 %
# education/3/majors/2 column - missing data percentage: 80.00 %
# education/5/majors/0 column - missing data percentage: 80.00 %
# education/6/majors/0 column - missing data percentage: 90.00 %
# education/6/majors/1 column - missing data percentage: 90.00 %
# education/7/school/type column - missing data percentage: 90.00 %
# education/7/school/location/name column - missing data percentage: 90.00 %
# education/7/school/location/locality column - missing data percentage: 90.00 %
# education/7/school/location/region column - missing data percentage: 90.00 %
# education/7/school/location/country column - missing data percentage: 90.00 %
# education/7/gpa column - missing data percentage: 100.00 %
# education/7/degrees/0 column - missing data percentage: 90.00 %
# education/7/majors/0 column - missing data percentage: 90.00 %
# experience/2/company/location column - missing data percentage: 100.00 %
# experience/6/location_names/0 column - missing data percentage: 40.00 %
# education/0/school/location column - missing data percentage: 100.00 %
# location_names/16 column - missing data percentage: 90.00 %
# location_names/17 column - missing data percentage: 90.00 %
# location_names/18 column - missing data percentage: 90.00 %
# location_names/19 column - missing data percentage: 90.00 %
# location_names/20 column - missing data percentage: 90.00 %
# location_names/21 column - missing data percentage: 90.00 %
# location_names/22 column - missing data percentage: 90.00 %
# location_names/23 column - missing data percentage: 90.00 %
# location_names/24 column - missing data percentage: 90.00 %
# location_names/25 column - missing data percentage: 90.00 %
# location_names/26 column - missing data percentage: 90.00 %
# location_names/27 column - missing data percentage: 90.00 %
# location_names/28 column - missing data percentage: 90.00 %
# location_names/29 column - missing data percentage: 90.00 %
# location_names/30 column - missing data percentage: 90.00 %
# location_names/31 column - missing data percentage: 90.00 %
# regions/8 column - missing data percentage: 90.00 %
# regions/9 column - missing data percentage: 90.00 %
# experience/1/title/levels/1 column - missing data percentage: 90.00 %
# experience/4/company/location column - missing data percentage: 100.00 %
# education/1/school/location column - missing data percentage: 100.00 %
# education/4/majors/1 column - missing data percentage: 70.00 %
# skills/50 column - missing data percentage: 90.00 %
# skills/51 column - missing data percentage: 90.00 %
# skills/52 column - missing data percentage: 90.00 %
# skills/53 column - missing data percentage: 90.00 %
# skills/54 column - missing data percentage: 90.00 %
# skills/55 column - missing data percentage: 90.00 %
# skills/56 column - missing data percentage: 90.00 %
# skills/57 column - missing data percentage: 90.00 %
# skills/58 column - missing data percentage: 90.00 %
# skills/59 column - missing data percentage: 90.00 %
# skills/60 column - missing data percentage: 90.00 %
# skills/61 column - missing data percentage: 90.00 %
# skills/62 column - missing data percentage: 90.00 %
# skills/63 column - missing data percentage: 90.00 %
# skills/64 column - missing data percentage: 90.00 %
# skills/65 column - missing data percentage: 90.00 %
# skills/66 column - missing data percentage: 90.00 %
# skills/67 column - missing data percentage: 90.00 %
# skills/68 column - missing data percentage: 90.00 %
# skills/69 column - missing data percentage: 90.00 %
# skills/70 column - missing data percentage: 90.00 %
# experience/9/title/levels/1 column - missing data percentage: 90.00 %
# experience/10/company/size column - missing data percentage: 90.00 %
# experience/10/company/industry column - missing data percentage: 90.00 %
# experience/10/company/location/name column - missing data percentage: 90.00 %
# experience/10/company/location/locality column - missing data percentage: 90.00 %
# experience/10/company/location/region column - missing data percentage: 90.00 %
# experience/10/company/location/country column - missing data percentage: 90.00 %
# experience/10/company/location/address_line_2 column - missing data percentage: 100.00 %
# experience/10/title/name column - missing data percentage: 90.00 %
# experience/10/title/role column - missing data percentage: 100.00 %
# experience/10/title/sub_role column - missing data percentage: 100.00 %
# experience/10/title/levels/0 column - missing data percentage: 90.00 %
# education/0/majors/0 column - missing data percentage: 80.00 %
# education/0/majors/1 column - missing data percentage: 90.00 %
# education/1/majors/1 column - missing data percentage: 90.00 %
# education/1/majors/2 column - missing data percentage: 90.00 %
# education/4/majors/2 column - missing data percentage: 90.00 %
# row_num column - missing data percentage: 0.00 %

# %% [markdown]
# Dealing with missing data - using median value

# %%
def fill_na(column):
    if column.isnumeric():
        print(X_train[column])
        X_train[column].fillna(X_train[column].median(), inplace=True)
    else:
        X_train[column].fillna(X_train[column].mode()[0], inplace=True)

# %%
for column in X_train.columns:
    fill_na(column)

# %% [markdown]
# Checking again if the attributes hold any missing values.

# %%
for column in X_train.columns:
    percentage = missing_data_percentage(column)
    print(percentage)
# Out:
# id column - missing data percentage: 0.00 %
# 0.0
# full_name column - missing data percentage: 0.00 %
# 0.0
# first_name column - missing data percentage: 0.00 %
# 0.0
# last_name column - missing data percentage: 0.00 %
# 0.0
# gender column - missing data percentage: 0.00 %
# 0.0
# birth_year column - missing data percentage: 0.00 %
# 0.0
# birth_date column - missing data percentage: 0.00 %
# 0.0
# linkedin_url column - missing data percentage: 0.00 %
# 0.0
# linkedin_username column - missing data percentage: 0.00 %
# 0.0
# linkedin_id column - missing data percentage: 0.00 %
# 0.0
# facebook_url column - missing data percentage: 0.00 %
# 0.0
# facebook_username column - missing data percentage: 0.00 %
# 0.0
# facebook_id column - missing data percentage: 0.00 %
# 0.0
# work_email column - missing data percentage: 0.00 %
# 0.0
# personal_emails/0 column - missing data percentage: 0.00 %
# 0.0
# personal_emails/1 column - missing data percentage: 0.00 %
# 0.0
# mobile_phone column - missing data percentage: 0.00 %
# 0.0
# industry column - missing data percentage: 0.00 %
# 0.0
# job_title column - missing data percentage: 0.00 %
# 0.0
# job_title_levels/0 column - missing data percentage: 0.00 %
# 0.0
# job_company_id column - missing data percentage: 0.00 %
# 0.0
# job_company_name column - missing data percentage: 0.00 %
# 0.0
# job_company_website column - missing data percentage: 0.00 %
# 0.0
# job_company_size column - missing data percentage: 0.00 %
# 0.0
# job_company_founded column - missing data percentage: 0.00 %
# 0.0
# job_company_industry column - missing data percentage: 0.00 %
# 0.0
# job_company_linkedin_url column - missing data percentage: 0.00 %
# 0.0
# job_company_linkedin_id column - missing data percentage: 0.00 %
# 0.0
# job_company_facebook_url column - missing data percentage: 0.00 %
# 0.0
# job_company_twitter_url column - missing data percentage: 0.00 %
# 0.0
# job_company_location_name column - missing data percentage: 0.00 %
# 0.0
# job_company_location_locality column - missing data percentage: 0.00 %
# 0.0
# job_company_location_metro column - missing data percentage: 0.00 %
# 0.0
# job_company_location_region column - missing data percentage: 0.00 %
# 0.0
# job_company_location_geo column - missing data percentage: 0.00 %
# 0.0
# job_company_location_street_address column - missing data percentage: 0.00 %
# 0.0
# job_company_location_postal_code column - missing data percentage: 0.00 %
# 0.0
# job_company_location_country column - missing data percentage: 0.00 %
# 0.0
# job_company_location_continent column - missing data percentage: 0.00 %
# 0.0
# job_last_updated column - missing data percentage: 0.00 %
# 0.0
# job_start_date column - missing data percentage: 0.00 %
# 0.0
# location_name column - missing data percentage: 0.00 %
# 0.0
# location_locality column - missing data percentage: 0.00 %
# 0.0
# location_metro column - missing data percentage: 0.00 %
# 0.0
# location_region column - missing data percentage: 0.00 %
# 0.0
# location_country column - missing data percentage: 0.00 %
# 0.0
# location_continent column - missing data percentage: 0.00 %
# 0.0
# location_street_address column - missing data percentage: 0.00 %
# 0.0
# location_postal_code column - missing data percentage: 0.00 %
# 0.0
# location_geo column - missing data percentage: 0.00 %
# 0.0
# location_last_updated column - missing data percentage: 0.00 %
# 0.0
# phone_numbers/0 column - missing data percentage: 0.00 %
# 0.0
# phone_numbers/1 column - missing data percentage: 0.00 %
# 0.0
# emails/0/address column - missing data percentage: 0.00 %
# 0.0
# emails/0/type column - missing data percentage: 0.00 %
# 0.0
# emails/1/address column - missing data percentage: 0.00 %
# 0.0
# emails/1/type column - missing data percentage: 0.00 %
# 0.0
# emails/2/address column - missing data percentage: 0.00 %
# 0.0
# emails/2/type column - missing data percentage: 0.00 %
# 0.0
# interests/0 column - missing data percentage: 0.00 %
# 0.0
# interests/1 column - missing data percentage: 0.00 %
# 0.0
# interests/2 column - missing data percentage: 0.00 %
# 0.0
# interests/3 column - missing data percentage: 0.00 %
# 0.0
# interests/4 column - missing data percentage: 0.00 %
# 0.0
# skills/0 column - missing data percentage: 0.00 %
# 0.0
# skills/1 column - missing data percentage: 0.00 %
# 0.0
# skills/2 column - missing data percentage: 0.00 %
# 0.0
# skills/3 column - missing data percentage: 0.00 %
# 0.0
# skills/4 column - missing data percentage: 0.00 %
# 0.0
# skills/5 column - missing data percentage: 0.00 %
# 0.0
# skills/6 column - missing data percentage: 0.00 %
# 0.0
# skills/7 column - missing data percentage: 0.00 %
# 0.0
# skills/8 column - missing data percentage: 0.00 %
# 0.0
# skills/9 column - missing data percentage: 0.00 %
# 0.0
# skills/10 column - missing data percentage: 0.00 %
# 0.0
# skills/11 column - missing data percentage: 0.00 %
# 0.0
# skills/12 column - missing data percentage: 0.00 %
# 0.0
# skills/13 column - missing data percentage: 0.00 %
# 0.0
# skills/14 column - missing data percentage: 0.00 %
# 0.0
# skills/15 column - missing data percentage: 0.00 %
# 0.0
# skills/16 column - missing data percentage: 0.00 %
# 0.0
# skills/17 column - missing data percentage: 0.00 %
# 0.0
# skills/18 column - missing data percentage: 0.00 %
# 0.0
# skills/19 column - missing data percentage: 0.00 %
# 0.0
# skills/20 column - missing data percentage: 0.00 %
# 0.0
# skills/21 column - missing data percentage: 0.00 %
# 0.0
# skills/22 column - missing data percentage: 0.00 %
# 0.0
# skills/23 column - missing data percentage: 0.00 %
# 0.0
# skills/24 column - missing data percentage: 0.00 %
# 0.0
# location_names/0 column - missing data percentage: 0.00 %
# 0.0
# location_names/1 column - missing data percentage: 0.00 %
# 0.0
# location_names/2 column - missing data percentage: 0.00 %
# 0.0
# location_names/3 column - missing data percentage: 0.00 %
# 0.0
# regions/0 column - missing data percentage: 0.00 %
# 0.0
# countries/0 column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/0/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/1/geo column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/location/locality column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/location/region column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/location/geo column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/0/company/website column - missing data percentage: 0.00 %
# 0.0
# experience/0/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/0/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/0/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/0/title/role column - missing data percentage: 0.00 %
# 0.0
# experience/0/title/levels/0 column - missing data percentage: 0.00 %
# 0.0
# experience/0/is_primary column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/locality column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/region column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/metro column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/street_address column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/postal_code column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/location/geo column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/twitter_url column - missing data percentage: 0.00 %
# 0.0
# experience/1/company/website column - missing data percentage: 0.00 %
# 0.0
# experience/1/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/1/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/1/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/1/title/role column - missing data percentage: 0.00 %
# 0.0
# experience/1/is_primary column - missing data percentage: 0.00 %
# 0.0
# education/0/school/name column - missing data percentage: 0.00 %
# 0.0
# education/0/school/type column - missing data percentage: 0.00 %
# 0.0
# education/0/school/id column - missing data percentage: 0.00 %
# 0.0
# education/0/school/location/name column - missing data percentage: 0.00 %
# 0.0
# education/0/school/location/locality column - missing data percentage: 0.00 %
# 0.0
# education/0/school/location/region column - missing data percentage: 0.00 %
# 0.0
# education/0/school/location/country column - missing data percentage: 0.00 %
# 0.0
# education/0/school/location/continent column - missing data percentage: 0.00 %
# 0.0
# education/0/school/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# education/0/school/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# education/0/school/website column - missing data percentage: 0.00 %
# 0.0
# education/0/school/domain column - missing data percentage: 0.00 %
# 0.0
# education/0/start_date column - missing data percentage: 0.00 %
# 0.0
# education/0/end_date column - missing data percentage: 0.00 %
# 0.0
# education/1/school/name column - missing data percentage: 0.00 %
# 0.0
# education/1/school/type column - missing data percentage: 0.00 %
# 0.0
# education/1/school/id column - missing data percentage: 0.00 %
# 0.0
# education/1/school/location/name column - missing data percentage: 0.00 %
# 0.0
# education/1/school/location/locality column - missing data percentage: 0.00 %
# 0.0
# education/1/school/location/region column - missing data percentage: 0.00 %
# 0.0
# education/1/school/location/country column - missing data percentage: 0.00 %
# 0.0
# education/1/school/location/continent column - missing data percentage: 0.00 %
# 0.0
# education/1/school/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# education/1/school/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# education/1/school/website column - missing data percentage: 0.00 %
# 0.0
# education/1/school/domain column - missing data percentage: 0.00 %
# 0.0
# education/1/start_date column - missing data percentage: 0.00 %
# 0.0
# education/1/end_date column - missing data percentage: 0.00 %
# 0.0
# profiles/0/network column - missing data percentage: 0.00 %
# 0.0
# profiles/0/id column - missing data percentage: 0.00 %
# 0.0
# profiles/0/url column - missing data percentage: 0.00 %
# 0.0
# profiles/0/username column - missing data percentage: 0.00 %
# 0.0
# profiles/1/network column - missing data percentage: 0.00 %
# 0.0
# profiles/1/id column - missing data percentage: 0.00 %
# 0.0
# profiles/1/url column - missing data percentage: 0.00 %
# 0.0
# profiles/1/username column - missing data percentage: 0.00 %
# 0.0
# profiles/2/network column - missing data percentage: 0.00 %
# 0.0
# profiles/2/url column - missing data percentage: 0.00 %
# 0.0
# profiles/2/username column - missing data percentage: 0.00 %
# 0.0
# version_status/status column - missing data percentage: 0.00 %
# 0.0
# version_status/previous_version column - missing data percentage: 0.00 %
# 0.0
# version_status/current_version column - missing data percentage: 0.00 %
# 0.0
# phone_numbers/2 column - missing data percentage: 0.00 %
# 0.0
# location_names/4 column - missing data percentage: 0.00 %
# 0.0
# location_names/5 column - missing data percentage: 0.00 %
# 0.0
# location_names/6 column - missing data percentage: 0.00 %
# 0.0
# location_names/7 column - missing data percentage: 0.00 %
# 0.0
# location_names/8 column - missing data percentage: 0.00 %
# 0.0
# regions/1 column - missing data percentage: 0.00 %
# 0.0
# regions/2 column - missing data percentage: 0.00 %
# 0.0
# regions/3 column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/2/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/3/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/4/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/5/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/6/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/7/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/metro column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/8/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/9/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/10/geo column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/name column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/locality column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/region column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/country column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/continent column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/street_address column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/postal_code column - missing data percentage: 0.00 %
# 0.0
# street_addresses/11/geo column - missing data percentage: 0.00 %
# 0.0
# experience/1/title/levels/0 column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/locality column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/region column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/metro column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/street_address column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/postal_code column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/location/geo column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/facebook_url column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/twitter_url column - missing data percentage: 0.00 %
# 0.0
# experience/2/company/website column - missing data percentage: 0.00 %
# 0.0
# experience/2/location_names/0 column - missing data percentage: 0.00 %
# 0.0
# experience/2/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/2/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/2/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/2/title/role column - missing data percentage: 0.00 %
# 0.0
# experience/2/title/levels/0 column - missing data percentage: 0.00 %
# 0.0
# experience/2/is_primary column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/locality column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/region column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/metro column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/street_address column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/postal_code column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/location/geo column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/3/company/website column - missing data percentage: 0.00 %
# 0.0
# experience/3/location_names/0 column - missing data percentage: 0.00 %
# 0.0
# experience/3/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/3/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/3/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/3/is_primary column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/4/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/4/location_names/0 column - missing data percentage: 0.00 %
# 0.0
# experience/4/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/4/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/4/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/4/title/role column - missing data percentage: 0.00 %
# 0.0
# experience/4/is_primary column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/locality column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/region column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/metro column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/street_address column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/postal_code column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/location/geo column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/facebook_url column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/twitter_url column - missing data percentage: 0.00 %
# 0.0
# experience/5/company/website column - missing data percentage: 0.00 %
# 0.0
# experience/5/location_names/0 column - missing data percentage: 0.00 %
# 0.0
# experience/5/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/5/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/5/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/5/is_primary column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/name column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/size column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/id column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/founded column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/industry column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/name column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/locality column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/region column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/metro column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/country column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/continent column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/street_address column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/postal_code column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/location/geo column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/facebook_url column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/twitter_url column - missing data percentage: 0.00 %
# 0.0
# experience/6/company/website column - missing data percentage: 0.00 %
# 0.0
# experience/6/end_date column - missing data percentage: 0.00 %
# 0.0
# experience/6/start_date column - missing data percentage: 0.00 %
# 0.0
# experience/6/title/name column - missing data percentage: 0.00 %
# 0.0
# experience/6/is_primary column - missing data percentage: 0.00 %
# 0.0
# education/0/degrees/0 column - missing data percentage: 0.00 %
# 0.0
# education/0/degrees/1 column - missing data percentage: 0.00 %
# 0.0
# education/2/school/name column - missing data percentage: 0.00 %
# 0.0
# education/2/school/type column - missing data percentage: 0.00 %
# 0.0
# education/2/school/id column - missing data percentage: 0.00 %
# 0.0
# education/2/school/location/name column - missing data percentage: 0.00 %
# 0.0
# education/2/school/location/country column - missing data percentage: 0.00 %
# 0.0
# education/2/school/location/continent column - missing data percentage: 0.00 %
# 0.0
# education/2/school/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# education/2/school/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# education/2/school/website column - missing data percentage: 0.00 %
# 0.0
# education/2/school/domain column - missing data percentage: 0.00 %
# 0.0
# education/2/end_date column - missing data percentage: 0.00 %
# 0.0
# education/2/degrees/0 column - missing data percentage: 0.00 %
# 0.0
# education/3/school/name column - missing data percentage: 0.00 %
# 0.0
# education/3/school/type column - missing data percentage: 0.00 %
# 0.0
# education/3/school/id column - missing data percentage: 0.00 %
# 0.0
# education/3/school/location/name column - missing data percentage: 0.00 %
# 0.0
# education/3/school/location/locality column - missing data percentage: 0.00 %
# 0.0
# education/3/school/location/region column - missing data percentage: 0.00 %
# 0.0
# education/3/school/location/country column - missing data percentage: 0.00 %
# 0.0
# education/3/school/location/continent column - missing data percentage: 0.00 %
# 0.0
# education/3/school/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# education/3/school/facebook_url column - missing data percentage: 0.00 %
# 0.0
# education/3/school/twitter_url column - missing data percentage: 0.00 %
# 0.0
# education/3/school/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# education/3/school/website column - missing data percentage: 0.00 %
# 0.0
# education/3/school/domain column - missing data percentage: 0.00 %
# 0.0
# education/3/end_date column - missing data percentage: 0.00 %
# 0.0
# education/3/start_date column - missing data percentage: 0.00 %
# 0.0
# education/3/degrees/0 column - missing data percentage: 0.00 %
# 0.0
# education/3/degrees/1 column - missing data percentage: 0.00 %
# 0.0
# education/4/school/name column - missing data percentage: 0.00 %
# 0.0
# education/4/school/type column - missing data percentage: 0.00 %
# 0.0
# education/4/school/id column - missing data percentage: 0.00 %
# 0.0
# education/4/school/location/name column - missing data percentage: 0.00 %
# 0.0
# education/4/school/location/locality column - missing data percentage: 0.00 %
# 0.0
# education/4/school/location/region column - missing data percentage: 0.00 %
# 0.0
# education/4/school/location/country column - missing data percentage: 0.00 %
# 0.0
# education/4/school/location/continent column - missing data percentage: 0.00 %
# 0.0
# education/4/school/linkedin_url column - missing data percentage: 0.00 %
# 0.0
# education/4/school/facebook_url column - missing data percentage: 0.00 %
# 0.0
# education/4/school/twitter_url column - missing data percentage: 0.00 %
# 0.0
# education/4/school/linkedin_id column - missing data percentage: 0.00 %
# 0.0
# education/4/school/website column - missing data percentage: 0.00 %
# 0.0
# education/4/school/domain column - missing data percentage: 0.00 %
# 0.0
# education/4/end_date column - missing data percentage: 0.00 %
# 0.0
# education/4/start_date column - missing data percentage: 0.00 %
# 0.0
# education/4/degrees/0 column - missing data percentage: 0.00 %
# 0.0
# education/4/degrees/1 column - missing data percentage: 0.00 %
# 0.0
# education/4/majors/0 column - missing data percentage: 0.00 %
# 0.0
# profiles/3/network column - missing data percentage: 0.00 %
# 0.0
# profiles/3/url column - missing data percentage: 0.00 %
# 0.0
# profiles/3/username column - missing data percentage: 0.00 %
# 0.0
# education/3/majors/0 column - missing data percentage: 0.00 %
# 0.0
# experience/6/location_names/0 column - missing data percentage: 0.00 %
# 0.0

# %% [markdown]
# # Data Outliers
# ****

# %% [markdown]
# The interquartile range (IQR) is a measure of statistical dispersion and is calculated as the difference between the 75th and 25th percentiles.
# It is represented by the formula IQR = Q3 − Q1.
# The lines of code below calculate and print the interquartile range for each of the variables in the dataset

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_columns = X_train.select_dtypes(include = numerics)
columns = num_columns.columns

Q1 = X_train[columns].quantile(0.25)
Q3 = X_train[columns].quantile(0.75)
IQR = Q3 - Q1

print(IQR)
# Out:
# birth_year    5.75
# row_num       4.50
# dtype: float64

# %% [markdown]
# Removing the outliers and calculating the skewness value again:

# %%
def transform_columns_flooring_capping(dataset, column):
    print("Skewness of column {} BEFORE the flooring and capping: {:.2f}".format(column, dataset[column].skew()))
    
    dataset[column] = np.where(dataset[column] < dataset[column].quantile(0.10), dataset[column].quantile(0.10), dataset[column])
    dataset[column] = np.where(dataset[column] > dataset[column].quantile(0.90), dataset[column].quantile(0.90), dataset[column])
    
    print("Skewness of column {} AFTER the flooring and capping: {:.2f}\n".format(column, dataset[column].skew()))
    return dataset[column]

# %%
for column in columns:
    transform_columns_flooring_capping(X_train, column)
# Out:
# Skewness of column birth_year BEFORE the flooring and capping: -2.00
# Skewness of column birth_year AFTER the flooring and capping: -1.57
#
# Skewness of column row_num BEFORE the flooring and capping: 0.00
# Skewness of column row_num AFTER the flooring and capping: -0.00

# %% [markdown]
# It is visible that removing the outliers below the 10th quantile and above 90th quantile results in better skewness of every column.

# %% [markdown]
# # Data Transformations
# ****

# %% [markdown]
# *Space for improvement: creating data transformers and calling them instead of the transformations above

# %% [markdown]
# Changing a date columns from object into datetime type:

# %%
len(X_train.columns)
# Out:
# 462

# %%
#X_train['date'] = pd.to_datetime(X_train['date'])

# %% [markdown]
# *** TODO* Changing numerical columns from object into datetime type, as well as other columns' types from object to float/int:***

# %%
X_train.infer_objects()
X_train.dtypes
# Out:
# id                               object
# full_name                        object
# first_name                       object
# last_name                        object
# gender                           object
#                                   ...
# profiles/3/network               object
# profiles/3/url                   object
# profiles/3/username              object
# education/3/majors/0             object
# experience/6/location_names/0    object
# Length: 462, dtype: object

# %% [markdown]
# There is a problem with columns named size, because some of them instead of the size in numbers (i.e. 100-500) have the 01 Oct.

# %%
for column in X_train.columns:
    if 'size' in column:
        X_train[column] = X_train[column].astype("string")

# %% [markdown]
# Removing other columns not significant for the similarity score and personal information (GDPR) data (name/middle name/surname/email/...) since only id column will be enough to get the information on the person

# %%
substrings = [
            'birth_date', 'phone_numbers',
            'website', 'facebook', 'twitter',
            'email', 'school/name', 'continent', 'company/id', 'school/id', 'is_primary',
            'company/name', 'location/geo', 'postal_code', 'gender', 'version_status', 'metro',
            'street', 'url',
            'start_date', 'end_date', 'profiles',
    'linkedin_username', 'linkedin_id', 'job_company_linkedin_id',
    'job_company_location_geo', 'job_last_updated', 'interests', 'founded', 'domain'
             ]

to_drop = []

for column in X_train.columns:
    for substring in substrings:
        if (substring in column):
            to_drop.append(column)

X_train = X_train.drop(to_drop, axis = 1)

# %%
X_train = X_train.drop(['full_name', 'first_name', 'last_name', 'mobile_phone'] ,axis = 1)

# %% [markdown]
# # Attributes Correlation
# ****

# %% [markdown]
# Pearson’s correlation coefficient is the test statistics that measures the statistical relationship, or association, between two continuous variables.
#
# When there are two independent variables that are very highly correlated, you definitely should remove one of them because you run into the multicollinearity conundrum and your regression model's coefficients related to the two highly correlated variables will be unreliable.

# %%
corr = X_train.corr()
corr
# Out:
#                                                middle_name  birth_year  \
# middle_name                                            NaN         NaN
# birth_year                                             NaN         1.0
# github_username                                        NaN         NaN
# job_title_role                                         NaN         NaN
# job_title_sub_role                                     NaN         NaN
# location_address_line_2                                NaN         NaN
# education/0/gpa                                        NaN         NaN
# education/1/gpa                                        NaN         NaN
# experience/0/company/location                          NaN         NaN
# experience/3/title/sub_role                            NaN         NaN
# experience/5/company/location/address_line_2           NaN         NaN
# experience/5/title/sub_role                            NaN         NaN
# experience/6/company/location/address_line_2           NaN         NaN
# experience/6/title/sub_role                            NaN         NaN
# experience/8/company/location/address_line_2           NaN         NaN
# experience/8/title/role                                NaN         NaN
# experience/8/title/sub_role                            NaN         NaN
# experience/9/company/location/address_line_2           NaN         NaN
# education/2/gpa                                        NaN         NaN
# education/3/gpa                                        NaN         NaN
# education/4/gpa                                        NaN         NaN
# education/5/gpa                                        NaN         NaN
# education/6/gpa                                        NaN         NaN
# experience/1/company/location                          NaN         NaN
# education/2/school/location                            NaN         NaN
# education/7/gpa                                        NaN         NaN
# experience/2/company/location                          NaN         NaN
# education/0/school/location                            NaN         NaN
# experience/4/company/location                          NaN         NaN
# education/1/school/location                            NaN         NaN
# experience/10/company/location/address_line_2          NaN         NaN
# experience/10/title/role                               NaN         NaN
# experience/10/title/sub_role                           NaN         NaN
#
#                                                github_username  \
# middle_name                                                NaN
# birth_year                                                 NaN
# github_username                                            NaN
# job_title_role                                             NaN
# job_title_sub_role                                         NaN
# location_address_line_2                                    NaN
# education/0/gpa                                            NaN
# education/1/gpa                                            NaN
# experience/0/company/location                              NaN
# experience/3/title/sub_role                                NaN
# experience/5/company/location/address_line_2               NaN
# experience/5/title/sub_role                                NaN
# experience/6/company/location/address_line_2               NaN
# experience/6/title/sub_role                                NaN
# experience/8/company/location/address_line_2               NaN
# experience/8/title/role                                    NaN
# experience/8/title/sub_role                                NaN
# experience/9/company/location/address_line_2               NaN
# education/2/gpa                                            NaN
# education/3/gpa                                            NaN
# education/4/gpa                                            NaN
# education/5/gpa                                            NaN
# education/6/gpa                                            NaN
# experience/1/company/location                              NaN
# education/2/school/location                                NaN
# education/7/gpa                                            NaN
# experience/2/company/location                              NaN
# education/0/school/location                                NaN
# experience/4/company/location                              NaN
# education/1/school/location                                NaN
# experience/10/company/location/address_line_2              NaN
# experience/10/title/role                                   NaN
# experience/10/title/sub_role                               NaN
#
#                                                job_title_role  \
# middle_name                                               NaN
# birth_year                                                NaN
# github_username                                           NaN
# job_title_role                                            NaN
# job_title_sub_role                                        NaN
# location_address_line_2                                   NaN
# education/0/gpa                                           NaN
# education/1/gpa                                           NaN
# experience/0/company/location                             NaN
# experience/3/title/sub_role                               NaN
# experience/5/company/location/address_line_2              NaN
# experience/5/title/sub_role                               NaN
# experience/6/company/location/address_line_2              NaN
# experience/6/title/sub_role                               NaN
# experience/8/company/location/address_line_2              NaN
# experience/8/title/role                                   NaN
# experience/8/title/sub_role                               NaN
# experience/9/company/location/address_line_2              NaN
# education/2/gpa                                           NaN
# education/3/gpa                                           NaN
# education/4/gpa                                           NaN
# education/5/gpa                                           NaN
# education/6/gpa                                           NaN
# experience/1/company/location                             NaN
# education/2/school/location                               NaN
# education/7/gpa                                           NaN
# experience/2/company/location                             NaN
# education/0/school/location                               NaN
# experience/4/company/location                             NaN
# education/1/school/location                               NaN
# experience/10/company/location/address_line_2             NaN
# experience/10/title/role                                  NaN
# experience/10/title/sub_role                              NaN
#
#                                                job_title_sub_role  \
# middle_name                                                   NaN
# birth_year                                                    NaN
# github_username                                               NaN
# job_title_role                                                NaN
# job_title_sub_role                                            NaN
# location_address_line_2                                       NaN
# education/0/gpa                                               NaN
# education/1/gpa                                               NaN
# experience/0/company/location                                 NaN
# experience/3/title/sub_role                                   NaN
# experience/5/company/location/address_line_2                  NaN
# experience/5/title/sub_role                                   NaN
# experience/6/company/location/address_line_2                  NaN
# experience/6/title/sub_role                                   NaN
# experience/8/company/location/address_line_2                  NaN
# experience/8/title/role                                       NaN
# experience/8/title/sub_role                                   NaN
# experience/9/company/location/address_line_2                  NaN
# education/2/gpa                                               NaN
# education/3/gpa                                               NaN
# education/4/gpa                                               NaN
# education/5/gpa                                               NaN
# education/6/gpa                                               NaN
# experience/1/company/location                                 NaN
# education/2/school/location                                   NaN
# education/7/gpa                                               NaN
# experience/2/company/location                                 NaN
# education/0/school/location                                   NaN
# experience/4/company/location                                 NaN
# education/1/school/location                                   NaN
# experience/10/company/location/address_line_2                 NaN
# experience/10/title/role                                      NaN
# experience/10/title/sub_role                                  NaN
#
#                                                location_address_line_2  \
# middle_name                                                        NaN
# birth_year                                                         NaN
# github_username                                                    NaN
# job_title_role                                                     NaN
# job_title_sub_role                                                 NaN
# location_address_line_2                                            NaN
# education/0/gpa                                                    NaN
# education/1/gpa                                                    NaN
# experience/0/company/location                                      NaN
# experience/3/title/sub_role                                        NaN
# experience/5/company/location/address_line_2                       NaN
# experience/5/title/sub_role                                        NaN
# experience/6/company/location/address_line_2                       NaN
# experience/6/title/sub_role                                        NaN
# experience/8/company/location/address_line_2                       NaN
# experience/8/title/role                                            NaN
# experience/8/title/sub_role                                        NaN
# experience/9/company/location/address_line_2                       NaN
# education/2/gpa                                                    NaN
# education/3/gpa                                                    NaN
# education/4/gpa                                                    NaN
# education/5/gpa                                                    NaN
# education/6/gpa                                                    NaN
# experience/1/company/location                                      NaN
# education/2/school/location                                        NaN
# education/7/gpa                                                    NaN
# experience/2/company/location                                      NaN
# education/0/school/location                                        NaN
# experience/4/company/location                                      NaN
# education/1/school/location                                        NaN
# experience/10/company/location/address_line_2                      NaN
# experience/10/title/role                                           NaN
# experience/10/title/sub_role                                       NaN
#
#                                                education/0/gpa  \
# middle_name                                                NaN
# birth_year                                                 NaN
# github_username                                            NaN
# job_title_role                                             NaN
# job_title_sub_role                                         NaN
# location_address_line_2                                    NaN
# education/0/gpa                                            NaN
# education/1/gpa                                            NaN
# experience/0/company/location                              NaN
# experience/3/title/sub_role                                NaN
# experience/5/company/location/address_line_2               NaN
# experience/5/title/sub_role                                NaN
# experience/6/company/location/address_line_2               NaN
# experience/6/title/sub_role                                NaN
# experience/8/company/location/address_line_2               NaN
# experience/8/title/role                                    NaN
# experience/8/title/sub_role                                NaN
# experience/9/company/location/address_line_2               NaN
# education/2/gpa                                            NaN
# education/3/gpa                                            NaN
# education/4/gpa                                            NaN
# education/5/gpa                                            NaN
# education/6/gpa                                            NaN
# experience/1/company/location                              NaN
# education/2/school/location                                NaN
# education/7/gpa                                            NaN
# experience/2/company/location                              NaN
# education/0/school/location                                NaN
# experience/4/company/location                              NaN
# education/1/school/location                                NaN
# experience/10/company/location/address_line_2              NaN
# experience/10/title/role                                   NaN
# experience/10/title/sub_role                               NaN
#
#                                                education/1/gpa  \
# middle_name                                                NaN
# birth_year                                                 NaN
# github_username                                            NaN
# job_title_role                                             NaN
# job_title_sub_role                                         NaN
# location_address_line_2                                    NaN
# education/0/gpa                                            NaN
# education/1/gpa                                            NaN
# experience/0/company/location                              NaN
# experience/3/title/sub_role                                NaN
# experience/5/company/location/address_line_2               NaN
# experience/5/title/sub_role                                NaN
# experience/6/company/location/address_line_2               NaN
# experience/6/title/sub_role                                NaN
# experience/8/company/location/address_line_2               NaN
# experience/8/title/role                                    NaN
# experience/8/title/sub_role                                NaN
# experience/9/company/location/address_line_2               NaN
# education/2/gpa                                            NaN
# education/3/gpa                                            NaN
# education/4/gpa                                            NaN
# education/5/gpa                                            NaN
# education/6/gpa                                            NaN
# experience/1/company/location                              NaN
# education/2/school/location                                NaN
# education/7/gpa                                            NaN
# experience/2/company/location                              NaN
# education/0/school/location                                NaN
# experience/4/company/location                              NaN
# education/1/school/location                                NaN
# experience/10/company/location/address_line_2              NaN
# experience/10/title/role                                   NaN
# experience/10/title/sub_role                               NaN
#
#                                                experience/0/company/location  \
# middle_name                                                              NaN
# birth_year                                                               NaN
# github_username                                                          NaN
# job_title_role                                                           NaN
# job_title_sub_role                                                       NaN
# location_address_line_2                                                  NaN
# education/0/gpa                                                          NaN
# education/1/gpa                                                          NaN
# experience/0/company/location                                            NaN
# experience/3/title/sub_role                                              NaN
# experience/5/company/location/address_line_2                             NaN
# experience/5/title/sub_role                                              NaN
# experience/6/company/location/address_line_2                             NaN
# experience/6/title/sub_role                                              NaN
# experience/8/company/location/address_line_2                             NaN
# experience/8/title/role                                                  NaN
# experience/8/title/sub_role                                              NaN
# experience/9/company/location/address_line_2                             NaN
# education/2/gpa                                                          NaN
# education/3/gpa                                                          NaN
# education/4/gpa                                                          NaN
# education/5/gpa                                                          NaN
# education/6/gpa                                                          NaN
# experience/1/company/location                                            NaN
# education/2/school/location                                              NaN
# education/7/gpa                                                          NaN
# experience/2/company/location                                            NaN
# education/0/school/location                                              NaN
# experience/4/company/location                                            NaN
# education/1/school/location                                              NaN
# experience/10/company/location/address_line_2                            NaN
# experience/10/title/role                                                 NaN
# experience/10/title/sub_role                                             NaN
#
#                                                experience/3/title/sub_role  \
# middle_name                                                            NaN
# birth_year                                                             NaN
# github_username                                                        NaN
# job_title_role                                                         NaN
# job_title_sub_role                                                     NaN
# location_address_line_2                                                NaN
# education/0/gpa                                                        NaN
# education/1/gpa                                                        NaN
# experience/0/company/location                                          NaN
# experience/3/title/sub_role                                            NaN
# experience/5/company/location/address_line_2                           NaN
# experience/5/title/sub_role                                            NaN
# experience/6/company/location/address_line_2                           NaN
# experience/6/title/sub_role                                            NaN
# experience/8/company/location/address_line_2                           NaN
# experience/8/title/role                                                NaN
# experience/8/title/sub_role                                            NaN
# experience/9/company/location/address_line_2                           NaN
# education/2/gpa                                                        NaN
# education/3/gpa                                                        NaN
# education/4/gpa                                                        NaN
# education/5/gpa                                                        NaN
# education/6/gpa                                                        NaN
# experience/1/company/location                                          NaN
# education/2/school/location                                            NaN
# education/7/gpa                                                        NaN
# experience/2/company/location                                          NaN
# education/0/school/location                                            NaN
# experience/4/company/location                                          NaN
# education/1/school/location                                            NaN
# experience/10/company/location/address_line_2                          NaN
# experience/10/title/role                                               NaN
# experience/10/title/sub_role                                           NaN
#
#                                                experience/5/company/location/address_line_2  \
# middle_name                                                                             NaN
# birth_year                                                                              NaN
# github_username                                                                         NaN
# job_title_role                                                                          NaN
# job_title_sub_role                                                                      NaN
# location_address_line_2                                                                 NaN
# education/0/gpa                                                                         NaN
# education/1/gpa                                                                         NaN
# experience/0/company/location                                                           NaN
# experience/3/title/sub_role                                                             NaN
# experience/5/company/location/address_line_2                                            NaN
# experience/5/title/sub_role                                                             NaN
# experience/6/company/location/address_line_2                                            NaN
# experience/6/title/sub_role                                                             NaN
# experience/8/company/location/address_line_2                                            NaN
# experience/8/title/role                                                                 NaN
# experience/8/title/sub_role                                                             NaN
# experience/9/company/location/address_line_2                                            NaN
# education/2/gpa                                                                         NaN
# education/3/gpa                                                                         NaN
# education/4/gpa                                                                         NaN
# education/5/gpa                                                                         NaN
# education/6/gpa                                                                         NaN
# experience/1/company/location                                                           NaN
# education/2/school/location                                                             NaN
# education/7/gpa                                                                         NaN
# experience/2/company/location                                                           NaN
# education/0/school/location                                                             NaN
# experience/4/company/location                                                           NaN
# education/1/school/location                                                             NaN
# experience/10/company/location/address_line_2                                           NaN
# experience/10/title/role                                                                NaN
# experience/10/title/sub_role                                                            NaN
#
#                                                experience/5/title/sub_role  \
# middle_name                                                            NaN
# birth_year                                                             NaN
# github_username                                                        NaN
# job_title_role                                                         NaN
# job_title_sub_role                                                     NaN
# location_address_line_2                                                NaN
# education/0/gpa                                                        NaN
# education/1/gpa                                                        NaN
# experience/0/company/location                                          NaN
# experience/3/title/sub_role                                            NaN
# experience/5/company/location/address_line_2                           NaN
# experience/5/title/sub_role                                            NaN
# experience/6/company/location/address_line_2                           NaN
# experience/6/title/sub_role                                            NaN
# experience/8/company/location/address_line_2                           NaN
# experience/8/title/role                                                NaN
# experience/8/title/sub_role                                            NaN
# experience/9/company/location/address_line_2                           NaN
# education/2/gpa                                                        NaN
# education/3/gpa                                                        NaN
# education/4/gpa                                                        NaN
# education/5/gpa                                                        NaN
# education/6/gpa                                                        NaN
# experience/1/company/location                                          NaN
# education/2/school/location                                            NaN
# education/7/gpa                                                        NaN
# experience/2/company/location                                          NaN
# education/0/school/location                                            NaN
# experience/4/company/location                                          NaN
# education/1/school/location                                            NaN
# experience/10/company/location/address_line_2                          NaN
# experience/10/title/role                                               NaN
# experience/10/title/sub_role                                           NaN
#
#                                                experience/6/company/location/address_line_2  \
# middle_name                                                                             NaN
# birth_year                                                                              NaN
# github_username                                                                         NaN
# job_title_role                                                                          NaN
# job_title_sub_role                                                                      NaN
# location_address_line_2                                                                 NaN
# education/0/gpa                                                                         NaN
# education/1/gpa                                                                         NaN
# experience/0/company/location                                                           NaN
# experience/3/title/sub_role                                                             NaN
# experience/5/company/location/address_line_2                                            NaN
# experience/5/title/sub_role                                                             NaN
# experience/6/company/location/address_line_2                                            NaN
# experience/6/title/sub_role                                                             NaN
# experience/8/company/location/address_line_2                                            NaN
# experience/8/title/role                                                                 NaN
# experience/8/title/sub_role                                                             NaN
# experience/9/company/location/address_line_2                                            NaN
# education/2/gpa                                                                         NaN
# education/3/gpa                                                                         NaN
# education/4/gpa                                                                         NaN
# education/5/gpa                                                                         NaN
# education/6/gpa                                                                         NaN
# experience/1/company/location                                                           NaN
# education/2/school/location                                                             NaN
# education/7/gpa                                                                         NaN
# experience/2/company/location                                                           NaN
# education/0/school/location                                                             NaN
# experience/4/company/location                                                           NaN
# education/1/school/location                                                             NaN
# experience/10/company/location/address_line_2                                           NaN
# experience/10/title/role                                                                NaN
# experience/10/title/sub_role                                                            NaN
#
#                                                experience/6/title/sub_role  \
# middle_name                                                            NaN
# birth_year                                                             NaN
# github_username                                                        NaN
# job_title_role                                                         NaN
# job_title_sub_role                                                     NaN
# location_address_line_2                                                NaN
# education/0/gpa                                                        NaN
# education/1/gpa                                                        NaN
# experience/0/company/location                                          NaN
# experience/3/title/sub_role                                            NaN
# experience/5/company/location/address_line_2                           NaN
# experience/5/title/sub_role                                            NaN
# experience/6/company/location/address_line_2                           NaN
# experience/6/title/sub_role                                            NaN
# experience/8/company/location/address_line_2                           NaN
# experience/8/title/role                                                NaN
# experience/8/title/sub_role                                            NaN
# experience/9/company/location/address_line_2                           NaN
# education/2/gpa                                                        NaN
# education/3/gpa                                                        NaN
# education/4/gpa                                                        NaN
# education/5/gpa                                                        NaN
# education/6/gpa                                                        NaN
# experience/1/company/location                                          NaN
# education/2/school/location                                            NaN
# education/7/gpa                                                        NaN
# experience/2/company/location                                          NaN
# education/0/school/location                                            NaN
# experience/4/company/location                                          NaN
# education/1/school/location                                            NaN
# experience/10/company/location/address_line_2                          NaN
# experience/10/title/role                                               NaN
# experience/10/title/sub_role                                           NaN
#
#                                                experience/8/company/location/address_line_2  \
# middle_name                                                                             NaN
# birth_year                                                                              NaN
# github_username                                                                         NaN
# job_title_role                                                                          NaN
# job_title_sub_role                                                                      NaN
# location_address_line_2                                                                 NaN
# education/0/gpa                                                                         NaN
# education/1/gpa                                                                         NaN
# experience/0/company/location                                                           NaN
# experience/3/title/sub_role                                                             NaN
# experience/5/company/location/address_line_2                                            NaN
# experience/5/title/sub_role                                                             NaN
# experience/6/company/location/address_line_2                                            NaN
# experience/6/title/sub_role                                                             NaN
# experience/8/company/location/address_line_2                                            NaN
# experience/8/title/role                                                                 NaN
# experience/8/title/sub_role                                                             NaN
# experience/9/company/location/address_line_2                                            NaN
# education/2/gpa                                                                         NaN
# education/3/gpa                                                                         NaN
# education/4/gpa                                                                         NaN
# education/5/gpa                                                                         NaN
# education/6/gpa                                                                         NaN
# experience/1/company/location                                                           NaN
# education/2/school/location                                                             NaN
# education/7/gpa                                                                         NaN
# experience/2/company/location                                                           NaN
# education/0/school/location                                                             NaN
# experience/4/company/location                                                           NaN
# education/1/school/location                                                             NaN
# experience/10/company/location/address_line_2                                           NaN
# experience/10/title/role                                                                NaN
# experience/10/title/sub_role                                                            NaN
#
#                                                experience/8/title/role  \
# middle_name                                                        NaN
# birth_year                                                         NaN
# github_username                                                    NaN
# job_title_role                                                     NaN
# job_title_sub_role                                                 NaN
# location_address_line_2                                            NaN
# education/0/gpa                                                    NaN
# education/1/gpa                                                    NaN
# experience/0/company/location                                      NaN
# experience/3/title/sub_role                                        NaN
# experience/5/company/location/address_line_2                       NaN
# experience/5/title/sub_role                                        NaN
# experience/6/company/location/address_line_2                       NaN
# experience/6/title/sub_role                                        NaN
# experience/8/company/location/address_line_2                       NaN
# experience/8/title/role                                            NaN
# experience/8/title/sub_role                                        NaN
# experience/9/company/location/address_line_2                       NaN
# education/2/gpa                                                    NaN
# education/3/gpa                                                    NaN
# education/4/gpa                                                    NaN
# education/5/gpa                                                    NaN
# education/6/gpa                                                    NaN
# experience/1/company/location                                      NaN
# education/2/school/location                                        NaN
# education/7/gpa                                                    NaN
# experience/2/company/location                                      NaN
# education/0/school/location                                        NaN
# experience/4/company/location                                      NaN
# education/1/school/location                                        NaN
# experience/10/company/location/address_line_2                      NaN
# experience/10/title/role                                           NaN
# experience/10/title/sub_role                                       NaN
#
#                                                experience/8/title/sub_role  \
# middle_name                                                            NaN
# birth_year                                                             NaN
# github_username                                                        NaN
# job_title_role                                                         NaN
# job_title_sub_role                                                     NaN
# location_address_line_2                                                NaN
# education/0/gpa                                                        NaN
# education/1/gpa                                                        NaN
# experience/0/company/location                                          NaN
# experience/3/title/sub_role                                            NaN
# experience/5/company/location/address_line_2                           NaN
# experience/5/title/sub_role                                            NaN
# experience/6/company/location/address_line_2                           NaN
# experience/6/title/sub_role                                            NaN
# experience/8/company/location/address_line_2                           NaN
# experience/8/title/role                                                NaN
# experience/8/title/sub_role                                            NaN
# experience/9/company/location/address_line_2                           NaN
# education/2/gpa                                                        NaN
# education/3/gpa                                                        NaN
# education/4/gpa                                                        NaN
# education/5/gpa                                                        NaN
# education/6/gpa                                                        NaN
# experience/1/company/location                                          NaN
# education/2/school/location                                            NaN
# education/7/gpa                                                        NaN
# experience/2/company/location                                          NaN
# education/0/school/location                                            NaN
# experience/4/company/location                                          NaN
# education/1/school/location                                            NaN
# experience/10/company/location/address_line_2                          NaN
# experience/10/title/role                                               NaN
# experience/10/title/sub_role                                           NaN
#
#                                                experience/9/company/location/address_line_2  \
# middle_name                                                                             NaN
# birth_year                                                                              NaN
# github_username                                                                         NaN
# job_title_role                                                                          NaN
# job_title_sub_role                                                                      NaN
# location_address_line_2                                                                 NaN
# education/0/gpa                                                                         NaN
# education/1/gpa                                                                         NaN
# experience/0/company/location                                                           NaN
# experience/3/title/sub_role                                                             NaN
# experience/5/company/location/address_line_2                                            NaN
# experience/5/title/sub_role                                                             NaN
# experience/6/company/location/address_line_2                                            NaN
# experience/6/title/sub_role                                                             NaN
# experience/8/company/location/address_line_2                                            NaN
# experience/8/title/role                                                                 NaN
# experience/8/title/sub_role                                                             NaN
# experience/9/company/location/address_line_2                                            NaN
# education/2/gpa                                                                         NaN
# education/3/gpa                                                                         NaN
# education/4/gpa                                                                         NaN
# education/5/gpa                                                                         NaN
# education/6/gpa                                                                         NaN
# experience/1/company/location                                                           NaN
# education/2/school/location                                                             NaN
# education/7/gpa                                                                         NaN
# experience/2/company/location                                                           NaN
# education/0/school/location                                                             NaN
# experience/4/company/location                                                           NaN
# education/1/school/location                                                             NaN
# experience/10/company/location/address_line_2                                           NaN
# experience/10/title/role                                                                NaN
# experience/10/title/sub_role                                                            NaN
#
#                                                education/2/gpa  \
# middle_name                                                NaN
# birth_year                                                 NaN
# github_username                                            NaN
# job_title_role                                             NaN
# job_title_sub_role                                         NaN
# location_address_line_2                                    NaN
# education/0/gpa                                            NaN
# education/1/gpa                                            NaN
# experience/0/company/location                              NaN
# experience/3/title/sub_role                                NaN
# experience/5/company/location/address_line_2               NaN
# experience/5/title/sub_role                                NaN
# experience/6/company/location/address_line_2               NaN
# experience/6/title/sub_role                                NaN
# experience/8/company/location/address_line_2               NaN
# experience/8/title/role                                    NaN
# experience/8/title/sub_role                                NaN
# experience/9/company/location/address_line_2               NaN
# education/2/gpa                                            NaN
# education/3/gpa                                            NaN
# education/4/gpa                                            NaN
# education/5/gpa                                            NaN
# education/6/gpa                                            NaN
# experience/1/company/location                              NaN
# education/2/school/location                                NaN
# education/7/gpa                                            NaN
# experience/2/company/location                              NaN
# education/0/school/location                                NaN
# experience/4/company/location                              NaN
# education/1/school/location                                NaN
# experience/10/company/location/address_line_2              NaN
# experience/10/title/role                                   NaN
# experience/10/title/sub_role                               NaN
#
#                                                education/3/gpa  \
# middle_name                                                NaN
# birth_year                                                 NaN
# github_username                                            NaN
# job_title_role                                             NaN
# job_title_sub_role                                         NaN
# location_address_line_2                                    NaN
# education/0/gpa                                            NaN
# education/1/gpa                                            NaN
# ...
# education/0/gpa                                                        NaN
# education/1/gpa                                                        NaN
# experience/0/company/location                                          NaN
# experience/3/title/sub_role                                            NaN
# experience/5/company/location/address_line_2                           NaN
# experience/5/title/sub_role                                            NaN
# experience/6/company/location/address_line_2                           NaN
# experience/6/title/sub_role                                            NaN
# experience/8/company/location/address_line_2                           NaN
# experience/8/title/role                                                NaN
# experience/8/title/sub_role                                            NaN
# experience/9/company/location/address_line_2                           NaN
# education/2/gpa                                                        NaN
# education/3/gpa                                                        NaN
# education/4/gpa                                                        NaN
# education/5/gpa                                                        NaN
# education/6/gpa                                                        NaN
# experience/1/company/location                                          NaN
# education/2/school/location                                            NaN
# education/7/gpa                                                        NaN
# experience/2/company/location                                          NaN
# education/0/school/location                                            NaN
# experience/4/company/location                                          NaN
# education/1/school/location                                            NaN
# experience/10/company/location/address_line_2                          NaN
# experience/10/title/role                                               NaN
# experience/10/title/sub_role                                           NaN
#
#                                                experience/4/company/location  \
# middle_name                                                              NaN
# birth_year                                                               NaN
# github_username                                                          NaN
# job_title_role                                                           NaN
# job_title_sub_role                                                       NaN
# location_address_line_2                                                  NaN
# education/0/gpa                                                          NaN
# education/1/gpa                                                          NaN
# experience/0/company/location                                            NaN
# experience/3/title/sub_role                                              NaN
# experience/5/company/location/address_line_2                             NaN
# experience/5/title/sub_role                                              NaN
# experience/6/company/location/address_line_2                             NaN
# experience/6/title/sub_role                                              NaN
# experience/8/company/location/address_line_2                             NaN
# experience/8/title/role                                                  NaN
# experience/8/title/sub_role                                              NaN
# experience/9/company/location/address_line_2                             NaN
# education/2/gpa                                                          NaN
# education/3/gpa                                                          NaN
# education/4/gpa                                                          NaN
# education/5/gpa                                                          NaN
# education/6/gpa                                                          NaN
# experience/1/company/location                                            NaN
# education/2/school/location                                              NaN
# education/7/gpa                                                          NaN
# experience/2/company/location                                            NaN
# education/0/school/location                                              NaN
# experience/4/company/location                                            NaN
# education/1/school/location                                              NaN
# experience/10/company/location/address_line_2                            NaN
# experience/10/title/role                                                 NaN
# experience/10/title/sub_role                                             NaN
#
#                                                education/1/school/location  \
# middle_name                                                            NaN
# birth_year                                                             NaN
# github_username                                                        NaN
# job_title_role                                                         NaN
# job_title_sub_role                                                     NaN
# location_address_line_2                                                NaN
# education/0/gpa                                                        NaN
# education/1/gpa                                                        NaN
# experience/0/company/location                                          NaN
# experience/3/title/sub_role                                            NaN
# experience/5/company/location/address_line_2                           NaN
# experience/5/title/sub_role                                            NaN
# experience/6/company/location/address_line_2                           NaN
# experience/6/title/sub_role                                            NaN
# experience/8/company/location/address_line_2                           NaN
# experience/8/title/role                                                NaN
# experience/8/title/sub_role                                            NaN
# experience/9/company/location/address_line_2                           NaN
# education/2/gpa                                                        NaN
# education/3/gpa                                                        NaN
# education/4/gpa                                                        NaN
# education/5/gpa                                                        NaN
# education/6/gpa                                                        NaN
# experience/1/company/location                                          NaN
# education/2/school/location                                            NaN
# education/7/gpa                                                        NaN
# experience/2/company/location                                          NaN
# education/0/school/location                                            NaN
# experience/4/company/location                                          NaN
# education/1/school/location                                            NaN
# experience/10/company/location/address_line_2                          NaN
# experience/10/title/role                                               NaN
# experience/10/title/sub_role                                           NaN
#
#                                                experience/10/company/location/address_line_2  \
# middle_name                                                                              NaN
# birth_year                                                                               NaN
# github_username                                                                          NaN
# job_title_role                                                                           NaN
# job_title_sub_role                                                                       NaN
# location_address_line_2                                                                  NaN
# education/0/gpa                                                                          NaN
# education/1/gpa                                                                          NaN
# experience/0/company/location                                                            NaN
# experience/3/title/sub_role                                                              NaN
# experience/5/company/location/address_line_2                                             NaN
# experience/5/title/sub_role                                                              NaN
# experience/6/company/location/address_line_2                                             NaN
# experience/6/title/sub_role                                                              NaN
# experience/8/company/location/address_line_2                                             NaN
# experience/8/title/role                                                                  NaN
# experience/8/title/sub_role                                                              NaN
# experience/9/company/location/address_line_2                                             NaN
# education/2/gpa                                                                          NaN
# education/3/gpa                                                                          NaN
# education/4/gpa                                                                          NaN
# education/5/gpa                                                                          NaN
# education/6/gpa                                                                          NaN
# experience/1/company/location                                                            NaN
# education/2/school/location                                                              NaN
# education/7/gpa                                                                          NaN
# experience/2/company/location                                                            NaN
# education/0/school/location                                                              NaN
# experience/4/company/location                                                            NaN
# education/1/school/location                                                              NaN
# experience/10/company/location/address_line_2                                            NaN
# experience/10/title/role                                                                 NaN
# experience/10/title/sub_role                                                             NaN
#
#                                                experience/10/title/role  \
# middle_name                                                         NaN
# birth_year                                                          NaN
# github_username                                                     NaN
# job_title_role                                                      NaN
# job_title_sub_role                                                  NaN
# location_address_line_2                                             NaN
# education/0/gpa                                                     NaN
# education/1/gpa                                                     NaN
# experience/0/company/location                                       NaN
# experience/3/title/sub_role                                         NaN
# experience/5/company/location/address_line_2                        NaN
# experience/5/title/sub_role                                         NaN
# experience/6/company/location/address_line_2                        NaN
# experience/6/title/sub_role                                         NaN
# experience/8/company/location/address_line_2                        NaN
# experience/8/title/role                                             NaN
# experience/8/title/sub_role                                         NaN
# experience/9/company/location/address_line_2                        NaN
# education/2/gpa                                                     NaN
# education/3/gpa                                                     NaN
# education/4/gpa                                                     NaN
# education/5/gpa                                                     NaN
# education/6/gpa                                                     NaN
# experience/1/company/location                                       NaN
# education/2/school/location                                         NaN
# education/7/gpa                                                     NaN
# experience/2/company/location                                       NaN
# education/0/school/location                                         NaN
# experience/4/company/location                                       NaN
# education/1/school/location                                         NaN
# experience/10/company/location/address_line_2                       NaN
# experience/10/title/role                                            NaN
# experience/10/title/sub_role                                        NaN
#
#                                                experience/10/title/sub_role
# middle_name                                                             NaN
# birth_year                                                              NaN
# github_username                                                         NaN
# job_title_role                                                          NaN
# job_title_sub_role                                                      NaN
# location_address_line_2                                                 NaN
# education/0/gpa                                                         NaN
# education/1/gpa                                                         NaN
# experience/0/company/location                                           NaN
# experience/3/title/sub_role                                             NaN
# experience/5/company/location/address_line_2                            NaN
# experience/5/title/sub_role                                             NaN
# experience/6/company/location/address_line_2                            NaN
# experience/6/title/sub_role                                             NaN
# experience/8/company/location/address_line_2                            NaN
# experience/8/title/role                                                 NaN
# experience/8/title/sub_role                                             NaN
# experience/9/company/location/address_line_2                            NaN
# education/2/gpa                                                         NaN
# education/3/gpa                                                         NaN
# education/4/gpa                                                         NaN
# education/5/gpa                                                         NaN
# education/6/gpa                                                         NaN
# experience/1/company/location                                           NaN
# education/2/school/location                                             NaN
# education/7/gpa                                                         NaN
# experience/2/company/location                                           NaN
# education/0/school/location                                             NaN
# experience/4/company/location                                           NaN
# education/1/school/location                                             NaN
# experience/10/company/location/address_line_2                           NaN
# experience/10/title/role                                                NaN
# experience/10/title/sub_role                                            NaN

# %% [markdown]
# Here we are taking only the upper triangle of the correlation matrix to remove only one highly correlated attribute (and to look only positive correlation (Pearson's coefficient ranges from -1 to 1)).

# %% [markdown]
# Generally, if the correlation between a pair of variables is greater than 0.5-0.6, we should seriously consider dropping one of those variables.
# We are selecting the columns which are having absolute correlation greater than 0.8 and making a list of those columns named 'to_drop'.

# %% [markdown]
# pearson's r = correlation coefficient = r:
#
# 0.00-0.19: very weak
# 0.20-0.39: weak
# 0.40-0.59: moderate
# 0.60-0.79: strong
# 0.80-1.00: very strong

# %%
upper_tri = corr.where(np.triu(np.ones(corr.shape),k=1).astype(np.bool))
# Out:
# <ipython-input-485-5563e36824c2>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_tri = corr.where(np.triu(np.ones(corr.shape),k=1).astype(np.bool))

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.8)]
print(to_drop)
# Out:
# []

# %% [markdown]
# Using Pearson's Correlation Coefficient, there is a couple of  variables that are highly correlated (𝜌 > 0.75)

# %%
X_train = X_train.drop(to_drop, axis = 1)

# %% [markdown]
# Number of columns in the dataset:

# %% [markdown]
# Adding row number column:

# %%
X_train['row_num'] = X_train.reset_index().index

# %%
X_train['education/4/school/domain']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'education/4/school/domain'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-490-530d965a1537> in <module>
# ----> 1 X_train['education/4/school/domain']
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'education/4/school/domain'

# %%
np.unique(X_train.columns)
# Out:
# array(['birth_year', 'countries/0', 'education/0/degrees/0',
#        'education/0/degrees/1', 'education/0/school/location/country',
#        'education/0/school/location/locality',
#        'education/0/school/location/name',
#        'education/0/school/location/region', 'education/0/school/type',
#        'education/1/school/location/country',
#        'education/1/school/location/locality',
#        'education/1/school/location/name',
#        'education/1/school/location/region', 'education/1/school/type',
#        'education/2/degrees/0', 'education/2/school/location/country',
#        'education/2/school/location/name', 'education/2/school/type',
#        'education/3/degrees/0', 'education/3/degrees/1',
#        'education/3/majors/0', 'education/3/school/location/country',
#        'education/3/school/location/locality',
#        'education/3/school/location/name',
#        'education/3/school/location/region', 'education/3/school/type',
#        'education/4/degrees/0', 'education/4/degrees/1',
#        'education/4/majors/0', 'education/4/school/location/country',
#        'education/4/school/location/locality',
#        'education/4/school/location/name',
#        'education/4/school/location/region', 'education/4/school/type',
#        'experience/0/company/industry',
#        'experience/0/company/location/country',
#        'experience/0/company/location/locality',
#        'experience/0/company/location/name',
#        'experience/0/company/location/region',
#        'experience/0/company/size', 'experience/0/title/levels/0',
#        'experience/0/title/name', 'experience/0/title/role',
#        'experience/1/company/industry',
#        'experience/1/company/location/country',
#        'experience/1/company/location/locality',
#        'experience/1/company/location/name',
#        'experience/1/company/location/region',
#        'experience/1/company/size', 'experience/1/title/levels/0',
#        'experience/1/title/name', 'experience/1/title/role',
#        'experience/2/company/industry',
#        'experience/2/company/location/country',
#        'experience/2/company/location/locality',
#        'experience/2/company/location/name',
#        'experience/2/company/location/region',
#        'experience/2/company/size', 'experience/2/location_names/0',
#        'experience/2/title/levels/0', 'experience/2/title/name',
#        'experience/2/title/role', 'experience/3/company/industry',
#        'experience/3/company/location/country',
#        'experience/3/company/location/locality',
#        'experience/3/company/location/name',
#        'experience/3/company/location/region',
#        'experience/3/company/size', 'experience/3/location_names/0',
#        'experience/3/title/name', 'experience/4/company/industry',
#        'experience/4/company/location/country',
#        'experience/4/company/location/name', 'experience/4/company/size',
#        'experience/4/location_names/0', 'experience/4/title/name',
#        'experience/4/title/role', 'experience/5/company/industry',
#        'experience/5/company/location/country',
#        'experience/5/company/location/locality',
#        'experience/5/company/location/name',
#        'experience/5/company/location/region',
#        'experience/5/company/size', 'experience/5/location_names/0',
#        'experience/5/title/name', 'experience/6/company/industry',
#        'experience/6/company/location/country',
#        'experience/6/company/location/locality',
#        'experience/6/company/location/name',
#        'experience/6/company/location/region',
#        'experience/6/company/size', 'experience/6/location_names/0',
#        'experience/6/title/name', 'id', 'industry', 'job_company_id',
#        'job_company_industry', 'job_company_location_country',
#        'job_company_location_locality', 'job_company_location_name',
#        'job_company_location_region', 'job_company_name',
#        'job_company_size', 'job_title', 'job_title_levels/0',
#        'location_country', 'location_geo', 'location_last_updated',
#        'location_locality', 'location_name', 'location_names/0',
#        'location_names/1', 'location_names/2', 'location_names/3',
#        'location_names/4', 'location_names/5', 'location_names/6',
#        'location_names/7', 'location_names/8', 'location_region',
#        'regions/0', 'regions/1', 'regions/2', 'regions/3', 'row_num',
#        'skills/0', 'skills/1', 'skills/10', 'skills/11', 'skills/12',
#        'skills/13', 'skills/14', 'skills/15', 'skills/16', 'skills/17',
#        'skills/18', 'skills/19', 'skills/2', 'skills/20', 'skills/21',
#        'skills/22', 'skills/23', 'skills/24', 'skills/3', 'skills/4',
#        'skills/5', 'skills/6', 'skills/7', 'skills/8', 'skills/9'],
#       dtype=object)

# %% [markdown]
# ## Explorative Data Analysis
# ****

# %% [markdown]
# Visualizing the candidates information:

# %%
dataset = X_train
#dataset = X_train.append(y_train)
#dataset = pd.merge(X_train, y_train, how = 'left', left_on = ["key", "month", "year"], right_on = ["key", "month", "year"])

# %% [markdown]
# Grouping data for EDA:

# %%
#total_sales_monthly_mean = dataset.groupby(["month"], as_index = False)["y"].mean()
#total_sales_monthly_sum = dataset.groupby(["month"], as_index = False)["y"].sum()

# %% [markdown]
# ## Total Number of Candidates by the Birth Year
# ****

# %%
#dataset["birth_year"].value_counts()

# %%
def plot_total_sales(measure):
    measure.plot(x = measure.columns[0], 
                 y = "y", 
                 figsize = (6, 4), 
                 title = "Sales - {}ly".format(measure.columns[0]), 
                 xlabel = measure.columns[0], 
                 ylabel = "Sales")

# %% [markdown]
# ## Sales by Product
# ****

# %%
def plot_sales_by_product(dataset):
    axes = plt.subplots(1, 1, figsize=(45, 15), sharex=True)
    ax = sn.barplot(x="key", y="y", data=dataset, palette="rocket").set_title("Yearly mean")
    plt.xticks(rotation = 90)
    plt.show()

# %% [markdown]
# # Feature Scaling
# ****

# %% [markdown]
# Standardization of datasets is a common requirement for many machine learning estimators implemented in scikit-learn; they might behave badly if the individual features do not more or less look like standard normally distributed data: Gaussian with zero mean and unit variance.
#
# Since we trained tree-based models on the data, feature scaling isn't needed.

# %% [markdown]
# # Transformations on the test set

# %% [markdown]
# Making the same transformations on the test set as on the training set:

# %%
X_test = X_test.drop(to_drop, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-252-197f5babcd41> in <module>
# ----> 1 X_test = X_test.drop(to_drop, axis = 1)
#
# NameError: name 'X_test' is not defined

# %%
X_test.drop(['x5', 'x6', 'x11', 'x17', 'x18', 'x25', 'x32', 'x39', 'x46', 'x53', 'x60', 'x67', 'x74', 'x81', 'x95', 'x102' ], axis = 1, inplace=True)

for column in X_test.iloc[:,2:].columns:
    fill_na(column)
    
for column in X_test.iloc[:,2:].columns:
    transform_columns_flooring_capping(X_test, column)
    
X_test['date'] = pd.to_datetime(X_test['date'])

X_test["month"] = pd.DatetimeIndex(X_test["date"]).month
X_test["year"] = pd.DatetimeIndex(X_test["date"]).year

X_test.infer_objects()

len(X_test.columns)

dataset = dataset.drop(["date_y"] ,axis = 1)
X_test = X_test.drop("date", axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-253-7930673b2aa8> in <module>
# ----> 1 X_test.drop(['x5', 'x6', 'x11', 'x17', 'x18', 'x25', 'x32', 'x39', 'x46', 'x53', 'x60', 'x67', 'x74', 'x81', 'x95', 'x102' ], axis = 1, inplace=True)
#       2
#       3 for column in X_test.iloc[:,2:].columns:
#       4     fill_na(column)
#       5
#
# NameError: name 'X_test' is not defined

# %% [markdown]
# # Similarity Measure - remove?
# ****

# %%
def compute_jaccard_similarity_score(x, y):
    """
    Jaccard Similarity J (A,B) = | Intersection (A,B) | /
                                    | Union (A,B) |
    """
    intersection_cardinality = len(set(x).intersection(set(y)))
    union_cardinality = len(set(x).union(set(y)))
    return intersection_cardinality / float(union_cardinality)

# %%
def find_match(user_id):
    res_max = 0
    idx = 0
    for i in range(len(X_train)):
        if (i != user_id):
            res = compute_jaccard_similarity_score(X_train.iloc[user_id].values, X_train.iloc[i].values)
            if res > res_max:
                res_max = res
                idx = i        
    return X_train.iloc[(X_train.index == user_id) | (X_train.index == idx)]

# %%
find_match(8)
# Out:
#                             id  birth_year       linkedin_username  \
# 0  iQI5CVMbb6pbBtfxN5Boaw_0000      1963.0  inguna-sotelo-9b000213
# 8  POJG1m0BG-KmBMt8H06LoA_0000      1960.7    lloyd-parker-2634875
#
#    linkedin_id                   facebook_url   facebook_id  \
# 0   44794644.0     facebook.com/inguna.sotelo  1.000012e+14
# 8   16103595.0  facebook.com/lloyd.parker.315  1.000000e+14
#
#                       work_email                         industry  \
# 0    inguna@independentequip.com  business supplies and equipment
# 8  lloyd.parker@twhiteparker.com            management consulting
#
#         job_title job_title_levels/0  ... education/4/end_date  \
# 0  vice president                 vp  ...               1990.0
# 8  vice president                 vp  ...               1990.0
#
#   education/4/degrees/0 education/4/degrees/1 education/4/majors/0  \
# 0             bachelors               masters            education
# 8             bachelors               masters            education
#
#    profiles/3/network               profiles/3/url profiles/3/username  \
# 0            facebook  facebook.com/dan.heneghan21            11223000
# 8            facebook  facebook.com/dan.heneghan21            11223000
#
#    education/3/majors/0      experience/6/location_names/0 row_num
# 0     civil engineering  new york, new york, united states       0
# 8     civil engineering  new york, new york, united states       8
#
# [2 rows x 433 columns]

# %%
compute_jaccard_similarity_score(X_train.iloc[2].values, X_train.iloc[4].values)
# Out:
# 0.1938534278959811

# %% [markdown]
# # Feature Importance
# ****

# %% [markdown]
# Tree-based estimators can be used to compute impurity-based feature importances, which in turn can be used to discard irrelevant features (when coupled with the SelectFromModel meta-transformer):

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100)
rf.fit(dataset.iloc[:,:-1], dataset.iloc[:,-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-292-12aab291e83b> in <module>
#       2
#       3 rf = RandomForestRegressor(n_estimators=100)
# ----> 4 rf.fit(dataset.iloc[:,:-1], dataset.iloc[:,-1])
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     301                 "sparse multilabel-indicator for y is not supported."
#     302             )
# --> 303         X, y = self._validate_data(X, y, multi_output=True,
#     304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# ValueError: could not convert string to float: 'iQI5CVMbb6pbBtfxN5Boaw_0000'

# %%
sorted_idx = rf.feature_importances_.argsort()

plt.figure(figsize=(15,15))
plt.barh(X_train.columns[sorted_idx], rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-259-0c08d923c626> in <module>
# ----> 1 sorted_idx = rf.feature_importances_.argsort()
#       2
#       3 plt.figure(figsize=(15,15))
#       4 plt.barh(X_train.columns[sorted_idx], rf.feature_importances_[sorted_idx])
#       5 plt.xlabel("Random Forest Feature Importance")
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in feature_importances_(self)
#     442             array of zeros.
#     443         """
# --> 444         check_is_fitted(self)
#     445
#     446         all_importances = Parallel(n_jobs=self.n_jobs,
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This RandomForestRegressor instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn.feature_selection import SelectFromModel
model = SelectFromModel(rf, prefit=True)
#X_new = model.transform(X_train)

# %% [markdown]
# It is visible that the most important features are key, year, month, x10, x109 and x22. We will make predictions on these variables.

# %% [markdown]
# # Creating the Model
# ****

# %% [markdown]
# ## KModes clustering

# %% [markdown]
# KModes clustering is one of the unsupervised Machine Learning algorithms that is used to cluster categorical variables.

# %%
from kmodes.kmodes import KModes

cost = []
K = range(1,5)

for num_clusters in list(K):
    kmode = KModes(n_clusters = num_clusters, init = "random", n_init = 5, verbose=1)
    kmode.fit_predict(X_train)
    cost.append(kmode.cost_)
    
plt.plot(K, cost, 'bx-')
plt.xlabel('No. of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 742.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 742.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 742.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 742.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 742.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 638.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 638.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 653.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 648.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 664.0
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 600.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 544.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 655.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 613.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 693.0
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 543.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 540.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 496.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 559.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 590.0
# Best run was number 3

# %%
# Building the model with 3 clusters

kmode = KModes(n_clusters = 3, init = "random", n_init = 5, verbose=1)
clusters = kmode.fit_predict(X_train)
clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 606.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 682.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 607.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 638.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 655.0
# Best run was number 1
# array([2, 2, 2, 1, 0, 2, 2, 0, 0, 0], dtype=uint16)

# %%
X_train["Cluster"] = clusters

# %%
X_train.head()
# Out:
#                             id  birth_year  \
# 0  iQI5CVMbb6pbBtfxN5Boaw_0000      1963.0
# 1  8waE0H55HkL60xQcjtVe7A_0000      1986.0
# 2  RcwvSHEBVA1-BVD4uQH3Bg_0000      1981.0
# 3  9k7BrMwL84x4Gcs9MmUQHQ_0000      1986.8
# 4  jtBLj1MfEyWbsKRDmGmftg_0000      1986.0
#
#                               industry       job_title job_title_levels/0  \
# 0      business supplies and equipment  vice president                 vp
# 1   non-profit organization management  vice president                 vp
# 2            marketing and advertising  vice president                 vp
# 3  information technology and services  vice president                 vp
# 4                   financial services  vice president                 vp
#
#                       job_company_id                   job_company_name  \
# 0          independent-equipment-llc          independent equipment llc
# 1  national-industries-for-the-blind  national industries for the blind
# 2                          videovets                          videovets
# 3         general-communications-inc                            gencomm
# 4                               citi                               citi
#
#   job_company_size                 job_company_industry  \
# 0           01-Oct      business supplies and equipment
# 1          201-500   non-profit organization management
# 2           01-Oct                     media production
# 3           51-200  information technology and services
# 4           10001+                   financial services
#
#                 job_company_location_name job_company_location_locality  \
# 0  house springs, missouri, united states                 house springs
# 1     alexandria, virginia, united states                    alexandria
# 2   sacramento, california, united states                    sacramento
# 3             draper, utah, united states                        draper
# 4       new york, new york, united states                      new york
#
#   job_company_location_region job_company_location_country  \
# 0                    missouri                united states
# 1                    virginia                united states
# 2                  california                united states
# 3                        utah                united states
# 4                    new york                united states
#
#                             location_name location_locality location_region  \
# 0  house springs, missouri, united states     house springs        missouri
# 1       manassas, virginia, united states          manassas        virginia
# 2   sacramento, california, united states        sacramento      california
# 3      rochester, new york, united states         rochester        new york
# 4      hempstead, new york, united states         hempstead        new york
#
#   location_country   location_geo location_last_updated  \
# 0    united states   38.40,-90.57            01/02/2021
# 1    united states   38.75,-77.47            01/10/2020
# 2    united states  38.58,-121.49            01/10/2020
# 3    united states   43.15,-77.61            01/01/2018
# 4    united states   40.70,-73.61            01/10/2020
#
#                 skills/0          skills/1                      skills/2  \
# 0              marketing       illustrator            strategic planning
# 1     program management        leadership  business process improvement
# 2  investment properties  customer service        first time home buyers
# 3            integration   troubleshooting                   electronics
# 4        policy analysis        government       environmental awareness
#
#            skills/3             skills/4              skills/5  \
# 0  sales management            packaging    corporate identity
# 1               dod           government   process improvement
# 2             sales          real estate      microsoft office
# 3                av  product development               testing
# 4          research        public policy  environmental policy
#
#              skills/6               skills/7            skills/8  \
# 0           photoshop         graphic design         logo design
# 1  security clearance      change management            military
# 2          management        microsoft excel     public speaking
# 3  video conferencing                  video  project management
# 4              policy  legislative relations          nonprofits
#
#              skills/9           skills/10               skills/11  \
# 0            graphics             posters              wayfinding
# 1    project planning  strategic planning                training
# 2          leadership  strategic planning  social media marketing
# 3         engineering                 cad                   sound
# 4  community outreach  program management           data analysis
#
#                skills/12          skills/13               skills/14  \
# 0     marketing strategy  brand development                 banners
# 1  management consulting         management  government contracting
# 2             powerpoint           research            social media
# 3    systems engineering      manufacturing                 autocad
# 4         sustainability   microsoft office                politics
#
#                              skills/15         skills/16  \
# 0                               layout               mac
# 1                              defense  proposal writing
# 2  working with first time home buyers    microsoft word
# 3                        system design    systems design
# 4                      public speaking       non profits
#
#               skills/17             skills/18         skills/19  \
# 0           trade shows  adobe creative suite         brochures
# 1  business development    project management           budgets
# 2               finance    project management         brochures
# 3              security       digital signage  microsoft office
# 4            powerpoint    project management         brochures
#
#              skills/20             skills/21            skills/22  \
# 0          book design  branded environments          calligraphy
# 1          procurement     national security            logistics
# 2  agile methodologies                   amx          calligraphy
# 3           automation                   amx  project engineering
# 4  agile methodologies                   amx          calligraphy
#
#                skills/23                skills/24  \
# 0           color theory     digital illustration
# 1                 policy  supply chain management
# 2           color theory                  defense
# 3  computer aided design        technical writing
# 4           color theory                  defense
#
#                                   location_names/0  \
# 0               jefferson, missouri, united states
# 1  washington, district of columbia, united states
# 2            sacramento, california, united states
# 3             san diego, california, united states
# 4                    houston, texas, united states
#
#                          location_names/1  \
# 0  house springs, missouri, united states
# 1    oceanside, california, united states
# 2      turlock, california, united states
# 3      la mesa, california, united states
# 4       new york, new york, united states
#
#                       location_names/2                      location_names/3  \
# 0   st. louis, missouri, united states  saint louis, missouri, united states
# 1      sunrise, florida, united states     manassas, virginia, united states
# 2  stockton, california, united states    oakdale, california, united states
# 3     herndon, virginia, united states            provo, utah, united states
# 4   hempstead, new york, united states     brooklyn, new york, united states
#
#                    regions/0    countries/0 experience/0/company/size  \
# 0    missouri, united states  united states                    01-Oct
# 1    virginia, united states  united states                    01-Oct
# 2  california, united states  united states                    51-200
# 3  california, united states  united states                    01-Oct
# 4    new york, united states  united states                    01-Oct
#
#      experience/0/company/industry      experience/0/company/location/name  \
# 0  business supplies and equipment  house springs, missouri, united states
# 1  business supplies and equipment         atlanta, georgia, united states
# 2                      real estate      modesto, california, united states
# 3  business supplies and equipment         atlanta, georgia, united states
# 4  business supplies and equipment         atlanta, georgia, united states
#
#   experience/0/company/location/locality experience/0/company/location/region  \
# 0                          house springs                             missouri
# 1                                atlanta                           california
# 2                                modesto                           california
# 3                                atlanta                           california
# 4                                atlanta                           california
#
#   experience/0/company/location/country     experience/0/title/name  \
# 0                         united states              vice president
# 1                         united states  owner and managing partner
# 2                         united states                loan officer
# 3                         united states              cad specialist
# 4                         united states                  co-founder
#
#   experience/0/title/role experience/0/title/levels/0  \
# 0                 finance                          vp
# 1                 finance                       owner
# 2                 finance                     manager
# 3                 finance                     manager
# 4                 finance                       owner
#
#   experience/1/company/size experience/1/company/industry  \
# 0                    01-Oct                graphic design
# 1                    10001+                      military
# 2                    10001+               defense & space
# 3                5001-10000                semiconductors
# 4                    10001+               defense & space
#
#                 experience/1/company/location/name  \
# 0             saint louis, missouri, united states
# 1  washington, district of columbia, united states
# 2                bethesda, maryland, united states
# 3              san jose, california, united states
# 4                bethesda, maryland, united states
#
#   experience/1/company/location/locality experience/1/company/location/region  \
# 0                            saint louis                             missouri
# 1                             washington                 district of columbia
# 2                               bethesda                           california
# 3                               san jose                           california
# 4                               bethesda                           california
#
#   experience/1/company/location/country  \
# 0                         united states
# 1                         united states
# 2                         united states
# 3                         united states
# 4                         united states
#
#                  experience/1/title/name experience/1/title/role  \
# 0                       graphic designer                  design
# 1                      leader of marines              operations
# 2                          film producer                   media
# 3  intern - high speed signal processing              operations
# 4                        program manager              operations
#
#       education/0/school/type       education/0/school/location/name  \
# 0  post-secondary institution   saint louis, missouri, united states
# 1  post-secondary institution    monterey, california, united states
# 2  post-secondary institution  sacramento, california, united states
# 3  post-secondary institution     rochester, new york, united states
# 4            secondary school  durham, north carolina, united states
#
#   education/0/school/location/locality education/0/school/location/region  \
# 0                          saint louis                           missouri
# 1                             monterey                         california
# 2                           sacramento                         california
# 3                            rochester                           new york
# 4                               durham                         california
#
#   education/0/school/location/country     education/1/school/type  \
# 0                       united states  post-secondary institution
# 1                       united states  post-secondary institution
# 2                       united states  post-secondary institution
# 3                       united states  post-secondary institution
# 4                       united states  post-secondary institution
#
#         education/1/school/location/name education/1/school/location/locality  \
# 0     st. louis, missouri, united states                            st. louis
# 1  fort belvoir, virginia, united states                         fort belvoir
# 2       davis, california, united states                                davis
# 3    salt lake city, utah, united states                       salt lake city
# 4           paris, île-de-france, france                                paris
#
#   education/1/school/location/region education/1/school/location/country  \
# 0                           missouri                       united states
# 1                           virginia                       united states
# 2                         california                       united states
# 3                               utah                       united states
# 4                      île-de-france                              france
#
#                            location_names/4  \
# 0  capitol heights, maryland, united states
# 1      sunnyvale, california, united states
# 2       san jose, california, united states
# 3        rochester, new york, united states
# 4  capitol heights, maryland, united states
#
#                            location_names/5  \
# 0  capitol heights, maryland, united states
# 1      centreville, virginia, united states
# 2        modesto, california, united states
# 3  capitol heights, maryland, united states
# 4  capitol heights, maryland, united states
#
#                        location_names/6  \
# 0    baltimore, maryland, united states
# 1    baltimore, maryland, united states
# 2  elk grove, california, united states
# 3    baltimore, maryland, united states
# 4    baltimore, maryland, united states
#
#                                     location_names/7  \
# 0                 baltimore, maryland, united states
# 1  district of columbia, district of columbia, un...
# 2               indianapolis, indiana, united states
# 3                 baltimore, maryland, united states
# 4                 baltimore, maryland, united states
#
#                          location_names/8                  regions/1  \
# 0            austin, texas, united states  california, united states
# 1  manassas park, virginia, united states     florida, united states
# 2            austin, texas, united states     indiana, united states
# 3            austin, texas, united states    virginia, united states
# 4            austin, texas, united states       texas, united states
#
#                    regions/2                            regions/3  \
# 0     arizona, united states  district of columbia, united states
# 1  california, united states  district of columbia, united states
# 2     arizona, united states  district of columbia, united states
# 3        utah, united states              new york, united states
# 4     arizona, united states  district of columbia, united states
#
#   experience/1/title/levels/0 experience/2/company/size  \
# 0                     manager                    10001+
# 1                     manager                    51-200
# 2                     manager                    01-Oct
# 3                    training                    10001+
# 4                     manager                    10001+
#
#          experience/2/company/industry     experience/2/company/location/name  \
# 0                      defense & space     arlington, virginia, united states
# 1  information technology and services     arlington, virginia, united states
# 2                     media production  sacramento, california, united states
# 3                      defense & space     arlington, virginia, united states
# 4     transportation/trucking/railroad      new york, new york, united states
#
#   experience/2/company/location/locality experience/2/company/location/region  \
# 0                              arlington                             virginia
# 1                              arlington                             virginia
# 2                             sacramento                           california
# 3                              arlington                             virginia
# 4                               new york                             new york
#
#   experience/2/company/location/country  \
# 0                         united states
# 1                         united states
# 2                         united states
# 3                         united states
# 4                         united states
#
#            experience/2/location_names/0  \
# 0      new york, new york, united states
# 1     arlington, virginia, united states
# 2  sacramento, california, united states
# 3      new york, new york, united states
# 4      new york, new york, united states
#
#                              experience/2/title/name experience/2/title/role  \
# 0           director, navy and marine corps programs              operations
# 1           director, navy and marine corps programs              operations
# 2                                     vice president              operations
# 3                                warehouse assistant              operations
# 4  sustainability initiatives and capital constru...                  trades
#
#   experience/2/title/levels/0 experience/3/company/size  \
# 0                     manager                 1001-5000
# 1                    director                    51-200
# 2                          vp                 1001-5000
# 3                     manager                    01-Oct
# 4                    training                    10001+
#
#   experience/3/company/industry  \
# 0                  law practice
# 1         management consulting
# 2                  law practice
# 3                        design
# 4            legislative office
#
#                 experience/3/company/location/name  \
# 0                new york, new york, united states
# 1            falls church, virginia, united states
# 2                new york, new york, united states
# 3               la mesa, california, united states
# 4  washington, district of columbia, united states
#
#   experience/3/company/location/locality experience/3/company/location/region  \
# 0                               new york                             virginia
# 1                           falls church                             virginia
# 2                               new york                             virginia
# 3                                la mesa                           california
# 4                             washington                 district of columbia
#
#   experience/3/company/location/country  \
# 0                         united states
# 1                         united states
# 2                         united states
# 3                         united states
# 4                         united states
#
#                      experience/3/location_names/0  \
# 0               arlington, virginia, united states
# 1            falls church, virginia, united states
# 2               arlington, virginia, united states
# 3               la mesa, california, united states
# 4  washington, district of columbia, united states
#
#                              experience/3/title/name  \
# 0                                     vice president
# 1                                     vice president
# 2                                     vice president
# 3                                              owner
# 4  house committee on oversight and government re...
#
#   experience/4/company/size experience/4/company/industry  \
# 0                    10001+     government administration
# 1                    10001+                      research
# 2                    10001+     government administration
# 3                 1001-5000              higher education
# 4                    10001+                  oil & energy
#
#     experience/4/company/location/name experience/4/company/location/country  \
# 0        columbus, ohio, united states                         united states
# 1        columbus, ohio, united states                         united states
# 2        columbus, ohio, united states                         united states
# 3  salt lake city, utah, united states                         united states
# 4      london, england, united kingdom                        united kingdom
#
#          experience/4/location_names/0  \
# 0   exton, pennsylvania, united states
# 1    stafford, virginia, united states
# 2   exton, pennsylvania, united states
# 3  salt lake city, utah, united states
# 4        houston, texas, united states
#
#                              experience/4/title/name experience/4/title/role  \
# 0                                 adjunct instructor              operations
# 1                        regional operations manager              operations
# 2                                 adjunct instructor              operations
# 3                                 adjunct instructor               education
# 4  remediation management - technical and busines...              operations
#
#   experience/5/company/size        experience/5/company/industry  \
# 0                    10001+                      defense & space
# 1                    10001+                             military
# 2                    10001+                      defense & space
# 3                    51-200  information technology and services
# 4                    10001+                         oil & energy
#
#                 experience/5/company/location/name  \
# 0                new york, new york, united states
# 1  washington, district of columbia, united states
# 2                new york, new york, united states
# 3                      draper, utah, united states
# 4                  london, england, united kingdom
#
#   experience/5/company/location/locality experience/5/company/location/region  \
# 0                               new york                             new york
# 1                             washington                 district of columbia
# 2                               new york                             new york
# 3                                 draper                                 utah
# 4                                 london                              england
#
#   experience/5/company/location/country       experience/5/location_names/0  \
# 0                         united states  baltimore, maryland, united states
# 1                         united states   quantico, virginia, united states
# 2                         united states  baltimore, maryland, united states
# 3                         united states  baltimore, maryland, united states
# 4                        united kingdom       houston, texas, united states
#
#                              experience/5/title/name  \
# 0                                     vice president
# 1                       director and program manager
# 2                                     vice president
# 3                                           engineer
# 4  health, safety, security, and environmental an...
#
#   experience/6/company/size        experience/6/company/industry  \
# 0                    10001+                         law practice
# 1                    10001+                             military
# 2                    10001+                         law practice
# 3                    51-200  information technology and services
# 4                    10001+                   financial services
#
#                 experience/6/company/location/name  \
# 0                new york, new york, united states
# 1  washington, district of columbia, united states
# 2                new york, new york, united states
# 3                      draper, utah, united states
# 4                new york, new york, united states
#
#   experience/6/company/location/locality experience/6/company/location/region  \
# 0                               new york                             new york
# 1                             washington                 district of columbia
# 2                               new york                             new york
# 3                                 draper                                 utah
# 4                               new york                             new york
#
#   experience/6/company/location/country experience/6/title/name  \
# 0                         united states               associate
# 1                         united states                director
# 2                         united states               associate
# 3                         united states          vice president
# 4                         united states          vice president
#
#      education/0/degrees/0 education/0/degrees/1     education/2/school/type  \
# 0  doctor of jurisprudence               masters  post-secondary institution
# 1        master of science               masters  post-secondary institution
# 2  doctor of jurisprudence            doctorates  post-secondary institution
# 3  doctor of jurisprudence               masters  post-secondary institution
# 4  doctor of jurisprudence               masters  post-secondary institution
#
#           education/2/school/location/name  \
# 0  cambridge, massachusetts, united states
# 1     montclair, new jersey, united states
# 2  cambridge, massachusetts, united states
# 3      salt lake city, utah, united states
# 4  cambridge, massachusetts, united states
#
#   education/2/school/location/country    education/2/degrees/0  \
# 0                       united states                bachelors
# 1                       united states                bachelors
# 2                       united states  doctor of jurisprudence
# 3                       united states                bachelors
# 4                       united states                bachelors
#
#       education/3/school/type        education/3/school/location/name  \
# 0  post-secondary institution         atlanta, georgia, united states
# 1  post-secondary institution     monterey, california, united states
# 2  post-secondary institution                   madrid, madrid, spain
# 3  post-secondary institution  los angeles, california, united states
# 4  post-secondary institution       new york, new york, united states
#
#   education/3/school/location/locality education/3/school/location/region  \
# 0                              atlanta                         california
# 1                             monterey                         california
# 2                               madrid                             madrid
# 3                          los angeles                         california
# 4                             new york                           new york
#
#   education/3/school/location/country education/3/degrees/0  \
# 0                       united states     master of science
# 1                       united states     master of science
# 2                               spain     master of science
# 3                       united states     master of science
# 4                       united states               masters
#
#                education/3/degrees/1     education/4/school/type  \
# 0                            masters  post-secondary institution
# 1  master of business administration  post-secondary institution
# 2                            masters  post-secondary institution
# 3                            masters  post-secondary institution
# 4    master of public administration  post-secondary institution
#
#                   education/4/school/location/name  \
# 0  washington, district of columbia, united states
# 1              monterey, california, united states
# 2            sacramento, california, united states
# 3           los angeles, california, united states
# 4  washington, district of columbia, united states
#
#   education/4/school/location/locality education/4/school/location/region  \
# 0                           washington                         california
# 1                             monterey                         california
# 2                           sacramento                         california
# 3                          los angeles                         california
# 4                           washington                         california
#
#   education/4/school/location/country    education/4/degrees/0  \
# 0                       united states                bachelors
# 1                       united states        master of science
# 2                       united states  doctor of jurisprudence
# 3                       united states                bachelors
# 4                       united states                bachelors
#
#   education/4/degrees/1    education/4/majors/0   education/3/majors/0  \
# 0               masters               education      civil engineering
# 1               masters              management      civil engineering
# 2            doctorates               education    film and television
# 3   bachelor of science  electrical engineering            engineering
# 4               masters               education  environmental science
#
#          experience/6/location_names/0  row_num  Cluster
# 0    new york, new york, united states      0.9        2
# 1    new york, new york, united states      1.0        2
# 2    new york, new york, united states      2.0        2
# 3  salt lake city, utah, united states      3.0        1
# 4    new york, new york, united states      4.0        0

# %%
kmode.cluster_centroids_
# Out:
# array([['POJG1m0BG-KmBMt8H06LoA_0000', '1986.0', 'cinematicac',
#         '16103595.0', 'financial services', 'vice president', 'vp',
#         'citi', 'citi', '01-Oct', '1844.4', 'financial services',
#         '10778.9', 'new york, new york, united states', 'new york',
#         'new york', '40.71,-74.00', 'united states', '01/06/2021',
#         'atlanta, georgia, united states', 'atlanta', 'california',
#         'united states', '33.74,-84.38', '01/10/2020', 'social services',
#         'children', 'economic empowerment',
#         'civil rights and social action', 'politics', 'corporate law',
#         'courts', 'business analysis', 'legal research',
#         'international development', 'corporate identity',
#         'business analysis', 'graphic design', 'logo design',
#         'bankruptcy', 'enterprise architecture',
#         'business process improvement', 'management consulting',
#         'brand development', 'autocad', 'defense', 'dod',
#         'business development', 'project management', 'brochures',
#         'agile methodologies', 'amx', 'calligraphy', 'color theory',
#         'defense', 'concord, new hampshire, united states',
#         'new york, new york, united states',
#         'ashburn, virginia, united states',
#         'brooklyn, new york, united states', 'new york, united states',
#         'united states', '01-Oct', '1992',
#         'business supplies and equipment',
#         'atlanta, georgia, united states', 'atlanta', 'california',
#         'united states', '39520.5', 'co-founder', 'finance', 'manager',
#         '10001+', 'None', 'defense & space',
#         'bethesda, maryland, united states', 'bethesda', 'california',
#         'united states', '1679.0', 'director of alumni relations',
#         'operations', 'post-secondary institution',
#         'durham, north carolina, united states', 'durham', 'california',
#         'united states', '18031.2', 'duke.edu',
#         'post-secondary institution', 'davis, california, united states',
#         'davis', 'california', 'united states', '15288.2',
#         'american.edu', 'capitol heights, maryland, united states',
#         'capitol heights, maryland, united states',
#         'baltimore, maryland, united states',
#         'baltimore, maryland, united states',
#         'austin, texas, united states', 'california, united states',
#         'arizona, united states', 'district of columbia, united states',
#         'manager', '10001+', 'None', 'defense & space',
#         'arlington, virginia, united states', 'arlington', 'virginia',
#         'united states', 'new york, new york, united states',
#         'director, navy and marine corps programs', 'operations',
#         'manager', '1001-5000', 'None', 'law practice',
#         'new york, new york, united states', 'new york', 'virginia',
#         'united states', 'arlington, virginia, united states',
#         'vice president', '10001+', 'None', 'government administration',
#         'columbus, ohio, united states', 'united states',
#         'exton, pennsylvania, united states', 'adjunct instructor',
#         'operations', '10001+', '1818.8', 'defense & space',
#         'new york, new york, united states', 'new york', 'new york',
#         'united states', 'baltimore, maryland, united states',
#         'vice president', '10001+', 'law practice',
#         'new york, new york, united states', 'new york', 'new york',
#         'united states', 'associate', 'doctor of jurisprudence',
#         'masters', 'post-secondary institution',
#         'cambridge, massachusetts, united states', 'united states',
#         'harvard.edu', 'bachelors', 'post-secondary institution',
#         'atlanta, georgia, united states', 'atlanta', 'california',
#         'united states', '16240.300000000001', 'columbia.edu',
#         'master of science', 'masters', 'post-secondary institution',
#         'washington, district of columbia, united states', 'washington',
#         'california', 'united states', 'american.edu', 'bachelors',
#         'masters', 'education', 'civil engineering',
#         'new york, new york, united states', '0', '2'],
#        ['8waE0H55HkL60xQcjtVe7A_0000', '1986.0',
#         'brandon-gramse-83675b18', '15250909.2',
#         'information technology and services', 'vice president', 'vp',
#         'general-communications-inc', 'gencomm', '201-500', '1938.0',
#         'information technology and services', '33885.0',
#         'alexandria, virginia, united states', 'alexandria', 'utah',
#         '38.80,-77.04', 'united states', '01/04/2021',
#         'manassas, virginia, united states', 'manassas', 'new york',
#         'united states', '38.75,-77.47', '01/01/2018', 'boating',
#         'children', 'children', 'civil rights and social action',
#         'politics', 'integration', 'leadership',
#         'business process improvement', 'av', 'government',
#         'process improvement', 'security clearance', 'change management',
#         'military', 'engineering', 'cad', 'sound',
#         'management consulting', 'management', 'autocad', 'defense',
#         'proposal writing', 'business development', 'digital signage',
#         'budgets', 'automation', 'amx', 'logistics',
#         'computer aided design', 'supply chain management',
#         'san diego, california, united states',
#         'la mesa, california, united states',
#         'herndon, virginia, united states',
#         'manassas, virginia, united states', 'california, united states',
#         'united states', '01-Oct', 'None',
#         'business supplies and equipment',
#         'atlanta, georgia, united states', 'atlanta', 'california',
#         'united states', '39520.5', 'cad specialist', 'finance',
#         'manager', '10001+', '1775', 'military',
#         'san jose, california, united states', 'san jose', 'california',
#         'united states', '2039.0',
#         'intern - high speed signal processing', 'operations',
#         'post-secondary institution',
#         'monterey, california, united states', 'monterey', 'california',
#         'united states', '20247.0', 'monroecc.edu',
#         'post-secondary institution',
#         'fort belvoir, virginia, united states', 'fort belvoir', 'utah',
#         'united states', '20126.0', 'dau.mil',
#         'rochester, new york, united states',
#         'capitol heights, maryland, united states',
#         'baltimore, maryland, united states',
#         'baltimore, maryland, united states',
#         'austin, texas, united states', 'florida, united states',
#         'california, united states',
#         'district of columbia, united states', 'manager', '10001+',
#         '1997', 'defense & space', 'arlington, virginia, united states',
#         'arlington', 'virginia', 'united states',
#         'arlington, virginia, united states',
#         'director, navy and marine corps programs', 'operations',
#         'director', '01-Oct', '2002', 'design',
#         'falls church, virginia, united states', 'falls church',
#         'california', 'united states',
#         'falls church, virginia, united states', 'owner', '10001+',
#         '1929', 'higher education', 'columbus, ohio, united states',
#         'united states', 'salt lake city, utah, united states',
#         'adjunct instructor', 'education', '10001+', '1818.8',
#         'information technology and services',
#         'draper, utah, united states', 'draper', 'district of columbia',
#         'united states', 'baltimore, maryland, united states',
#         'director and program manager', '10001+',
#         'information technology and services',
#         'draper, utah, united states', 'draper', 'district of columbia',
#         'united states', 'director', 'doctor of jurisprudence',
#         'masters', 'post-secondary institution',
#         'montclair, new jersey, united states', 'united states',
#         'montclair.edu', 'bachelors', 'post-secondary institution',
#         'los angeles, california, united states', 'los angeles',
#         'california', 'united states', '17971.0', 'nps.edu',
#         'master of science', 'master of business administration',
#         'post-secondary institution',
#         'los angeles, california, united states', 'los angeles',
#         'california', 'united states', 'nps.edu', 'bachelors',
#         'bachelor of science', 'electrical engineering',
#         'civil engineering', 'new york, new york, united states', '1',
#         '1'],
#        ['bKzMAJWff4gVN5HJHd1EKQ_0000', '1980.0',
#         'john-matlock-p-e-55589413', '46974737.0', 'defense & space',
#         'vice president', 'vp', 'matlock-and-associates',
#         'matlock & associates', 'Nov-50', '2011.0', 'defense & space',
#         '8097088.1', 'arlington, virginia, united states', 'arlington',
#         'virginia', '38.89,-77.08', 'united states', '01/04/2021',
#         'honey brook, pennsylvania, united states', 'honey brook',
#         'pennsylvania', 'united states', '40.09,-75.91', '01/07/2020',
#         'social services', 'economic empowerment',
#         'civil rights and social action', 'politics', 'education',
#         'program management', 'proposal writing', 'project management',
#         'project planning', 'management', 'construction management',
#         'leadership', 'engineering', 'construction',
#         'government contracting', 'military', 'earned value management',
#         'contract management', 'business development',
#         'customer service', 'quality control', 'dod', 'procurement',
#         'engineers', 'international project management', 'government',
#         'process improvement', 'global business development',
#         'professional services', 'defense',
#         'chester, virginia, united states',
#         'coatesville, pennsylvania, united states',
#         'metamora, illinois, united states',
#         'waipahu, hawaii, united states', 'virginia, united states',
#         'united states', '10001+', '1939', 'defense & space',
#         'falls church, virginia, united states', 'falls church',
#         'virginia', 'united states', '39520.5', 'project manager',
#         'operations', 'manager', '10001+', '1951', 'defense & space',
#         'mclean, virginia, united states', 'mclean', 'virginia',
#         'united states', '7005.0', 'senior project manager',
#         'operations', 'post-secondary institution',
#         'durham, north carolina, united states', 'durham', 'california',
#         'united states', '18031.2', 'duke.edu', 'secondary school',
#         'davis, california, united states', 'davis', 'california',
#         'united states', '15288.2', 'american.edu',
#         'honey brook, pennsylvania, united states',
#         'capitol heights, maryland, united states',
#         'san francisco, california, united states',
#         'downingtown, pennsylvania, united states',
#         'boston, massachusetts, united states',
#         'california, united states', 'arizona, united states',
#         'hawaii, united states', 'manager', '10001+', '1951',
#         'defense & space', 'mclean, virginia, united states', 'mclean',
#         'virginia', 'united states', 'new york, new york, united states',
#         'project manager civil engineer', 'operations', 'manager',
#         'Nov-50', '2011', 'defense & space',
#         'arlington, virginia, united states', 'arlington', 'virginia',
#         'united states', 'arlington, virginia, united states',
#         'vice president', '10001+', 'None', 'government administration',
#         'columbus, ohio, united states', 'united states',
#         'exton, pennsylvania, united states', 'civil design engineer',
#         'engineering', '10001+', '1947.0', 'defense & space',
#         'texas, united states', 'new york', 'texas', 'united states',
#         'baltimore, maryland, united states',
#         '175th air wing, 235th civil engineering flight', '51-200',
#         'architecture & planning',
#         'valley forge, pennsylvania, united states', 'valley forge',
#         'pennsylvania', 'united states', 'design structural engineer',
#         'master of business administration', 'masters',
#         'post-secondary institution',
#         'cambridge, massachusetts, united states', 'united states',
#         'harvard.edu', 'masters', 'post-secondary institution',
#         'morgantown, west virginia, united states', 'morgantown',
#         'west virginia', 'united states', '19712.0', 'wvu.edu',
#         'bachelors', 'bachelor of science', 'post-secondary institution',
#         'washington, district of columbia, united states', 'washington',
#         'district of columbia', 'united states', 'american.edu',
#         'master of business administration', 'masters',
#         'financial management', 'civil engineering',
#         'valley forge, pennsylvania, united states', '5', '2']],
#       dtype='<U47')

# %%
plt.scatter(X_train["Cluster"], X_train["Cluster"])

# %% [markdown]
# # Conclusion
# ****
#
# LightGBM model showed the best results when testing on the validation_set, with 39.7%. Next, we will change the hyperparameters to get the best values and to lower the WMAPE measure of error:

# %%
y_pred_val = model_lgb.predict(validation_set_features, num_iteration = model_lgb.best_iteration)

# %%
WMAPE(y_pred_val, validation_set_y)
# Out:
# 0.4
# WMAPE Score:  39.65  %

# %% [markdown]
# # Predictions on the Test Set
# ****

# %% [markdown]
# After taking only the most important features, using the best performing model on the validation set to predict test set results:

# %%
X_test_features = X_test[["key", "year", "month", "x10", "x22", "x85", "x92", "x109"]]

# %%
y_test = model_lgb.predict(X_test_features, num_iteration = model_lgb.best_iteration)

# %%
y_test = pd.DataFrame(y_test, columns = ["y"])

# %%
X_test
# Out:
#         key        x1        x2        x3      x4           x7          x8  \
# 0       683  0.000000  0.000000  0.397238  0.0000   119.936184  114.063630
# 1       683       NaN  0.000000  0.000000  0.0000   593.803092         NaN
# 2       683  0.000000  0.000000  0.000000  0.0000   222.106715    7.926074
# 3       683  0.607430  0.576041  0.000000  0.0000    59.588630  361.870894
# 4       683  0.000000  0.000000  0.000000  0.6485  1970.406869    6.444104
# ...     ...       ...       ...       ...     ...          ...         ...
# 1423  99444  0.167286  0.000000  0.000000  0.0000    28.683344  671.811450
# 1424  99444  0.000000  0.000000  0.000000  0.6485   114.679868    6.508677
# 1425  99444  0.317642  0.000000  0.000000     NaN  2674.140175  575.320377
# 1426  99444  0.000000  0.000000  0.598422  0.0000   677.526635    8.384144
# 1427  99444  0.000000  0.000000  0.000000  0.0000    16.100786   80.009016
#
#               x10        x12        x14  ...       x103       x105  \
# 0     6024.457359   0.462340   6.499243  ...   0.019900   0.000000
# 1     6024.457359        NaN        NaN  ...   0.000000   0.141846
# 2     3678.029954   1.158072   0.000000  ...  88.110086   1.003184
# 3     5274.149878   2.838254   2.142438  ...   6.852297  38.906611
# 4     4552.412721   0.102331   0.000000  ...  10.802692   1.605068
# ...           ...        ...        ...  ...        ...        ...
# 1423  6024.457359   8.320817  28.992993  ...   1.841767  38.906611
# 1424  6024.457359   0.000000   0.000000  ...   0.000000   0.000000
# 1425  6024.457359  80.750194   0.000000  ...   0.000000   0.284562
# 1426  6024.457359   0.629653   0.000000  ...   7.098375  13.501808
# 1427  6024.457359   0.000000   0.000000  ...  26.956189   0.000000
#
#              x106      x108        x109       x110       x112  month  year  \
# 0     2206.040376  0.000000   39.599762   7.289597  27.328970      7  2018
# 1      130.027455  0.357027   33.098055  17.244210   3.189301      8  2018
# 2             NaN       NaN    8.638553        NaN        NaN      9  2018
# 3      102.735687  0.000000   14.646718   2.719439   0.267833     10  2018
# 4       71.384402  0.000000    0.000000   2.190175   0.833723     11  2018
# ...           ...       ...         ...        ...        ...    ...   ...
# 1423    53.162367  0.000000   52.082725   0.764603   0.262702      2  2019
# 1424    11.386100  0.000000  142.196722   0.356890   0.000000      3  2019
# 1425     2.814448  0.000000  165.414227   0.038380   0.073461      4  2019
# 1426    28.990518  0.026931   58.296873   3.361134   0.000000      5  2019
# 1427    30.554309  0.000000  273.088747   0.000000   0.000000      6  2019
#
#         id
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 1423  1423
# 1424  1424
# 1425  1425
# 1426  1426
# 1427  1427
#
# [1428 rows x 71 columns]

# %%
X_test['id'] = np.arange(len(X_test))

# %%
y_test['id'] = np.arange(len(y_test))

# %% [markdown]
# combine x_test and y_test into y_test, and concat only 01 + month + year, and key and y prediction

# %%
y_test = pd.merge(y_test, X_test, left_on = "id", right_on = "id")

# %%
months = y_test['month'].astype(int)
month_abbr = []
date = []

for month in months:
    abbr = calendar.month_abbr[month]
    month_abbr.append(abbr)

for abbr in month_abbr:
    date.append("01" + abbr)
    
y_test['date'] = date + y_test['year'].astype(str)

# %%
y_test = y_test[["key", "date", "y"]]

# %%
y_test
# Out:
#         key       date            y
# 0       683  01Jul2018  5080.077683
# 1       683  01Aug2018  4286.903518
# 2       683  01Sep2018  3613.895160
# 3       683  01Oct2018  2900.301780
# 4       683  01Nov2018  2437.221981
# ...     ...        ...          ...
# 1423  99444  01Feb2019  3026.742473
# 1424  99444  01Mar2019  4804.224906
# 1425  99444  01Apr2019  5141.778987
# 1426  99444  01May2019  5849.527317
# 1427  99444  01Jun2019  6671.697500
#
# [1428 rows x 3 columns]

# %%
y_test.to_csv("y_test.csv")
